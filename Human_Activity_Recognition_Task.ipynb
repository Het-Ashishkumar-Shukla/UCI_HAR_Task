# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import tsfel
import sklearn

# %% [markdown]
# # **Dataset Preparation**
#
# ### Note: the input features have been converted to csv files before being read.

# %% [markdown]
# ## **Raw Accelerometer Data**

# %%
raw_train_signals_path='UCI HAR Dataset/train/Inertial Signals/'
raw_test_signals_path='UCI HAR Datase/test/Inertial Signals/'

# %%
raw_train_signals_x=pd.read_csv(os.path.join(raw_train_signals_path,'total_acc_x_train.csv'), header=None)
raw_train_signals_y=pd.read_csv(os.path.join(raw_train_signals_path,'total_acc_y_train.csv'), header=None)
raw_train_signals_z=pd.read_csv(os.path.join(raw_train_signals_path,'total_acc_z_train.csv'), header=None)

# %%
train_labels=pd.read_csv(os.path.join('UCI HAR Dataset/train','y_train.csv'), header=None)
test_labels=pd.read_csv(os.path.join('UCI HAR Dataset/test','y_test.csv'), header=None)
print(np.unique(train_labels))
print(np.unique(test_labels))
# Out:
# [1 2 3 4 5 6]
# [1 2 3 4 5 6]

# %%
X_train_raw=[]
y_train_raw=[]
for i, label in enumerate(train_labels.iloc[:,0]):
    acc_x=raw_train_signals_x.loc[i].values
    acc_y=raw_train_signals_y.loc[i].values
    acc_z=raw_train_signals_z.loc[i].values
    total_accel=np.stack((acc_x,acc_y,acc_z), axis=1)
    X_train_raw.append(total_accel)
    y_train_raw.append(label)
X_train_raw=np.array(X_train_raw)
y_train_raw=np.array(y_train_raw)

# %%
print(X_train_raw.shape)
print(y_train_raw.shape)
# Out:
# (7352, 128, 3)
# (7352,)

# %%
raw_test_signals_x=pd.read_csv(os.path.join(raw_test_signals_path,'total_acc_x_test.csv'), header=None)
raw_test_signals_y=pd.read_csv(os.path.join(raw_test_signals_path,'total_acc_y_test.csv'), header=None)
raw_test_signals_z=pd.read_csv(os.path.join(raw_test_signals_path,'total_acc_z_test.csv'), header=None)

# %%
X_test_raw=[]
y_test_raw=[]
for i, label in enumerate(test_labels.iloc[:,0]):
    acc_x=raw_test_signals_x.loc[i].values
    acc_y=raw_test_signals_y.loc[i].values
    acc_z=raw_test_signals_z.loc[i].values
    total_accel=np.stack((acc_x,acc_y,acc_z), axis=1)
    X_test_raw.append(total_accel)
    y_test_raw.append(label)
X_test_raw=np.array(X_test_raw)
y_test_raw=np.array(y_test_raw)

# %%
print(X_test_raw.shape)
print(y_test_raw.shape)
# Out:
# (2947, 128, 3)
# (2947,)

# %% [markdown]
# ## **Dataset from Features provided by author.**

# %%
features=[]
with open('UCI HAR Dataset/features.txt','r') as file:
    for line in file:
        feature=line.strip().split()[1]
        features.append(feature)

# %%
train_features=pd.read_csv(os.path.join('UCI HAR Dataset/train','X_train.csv'),header=None)
test_features=pd.read_csv(os.path.join('UCI HAR Dataset/test','X_test.csv'),header=None)

# %%
train_features.columns=features
test_features.columns=features

# %%
test_labels.columns=['Activity']

# %%
X_train_dataset_feat=np.array(train_features)
y_train_dataset_feat=np.array(train_labels)
X_test_dataset_feat=np.array(test_features)
y_test_dataset_feat=np.array(test_labels)

# %% [markdown]
# ## **Dataset from TSFEL features**

# %%
def get_tsfel_features(dataset, domain):
    tsfel_features_list=[]
    cfg=tsfel.get_features_by_domain(domain)
    for window in range(dataset.shape[0]):
        dataset_window_for_tsfel = pd.DataFrame(dataset[window], columns=['acc_x', 'acc_y', 'acc_z'])
        features_x=tsfel.time_series_features_extractor(cfg, dataset_window_for_tsfel[['acc_x']], fs=100, verbose=0)
        features_y=tsfel.time_series_features_extractor(cfg, dataset_window_for_tsfel[['acc_y']], fs=100, verbose=0)
        features_z=tsfel.time_series_features_extractor(cfg, dataset_window_for_tsfel[['acc_z']], fs=100, verbose=0)
        features=pd.concat([features_x, features_y, features_z], axis=1)
        tsfel_features_list.append(features)
        print(f'Extracted TSFEL features for window-{window+1}')
    tsfel_features_df=pd.concat(tsfel_features_list, ignore_index=True)
    return tsfel_features_df

# %%
X_train_tsfel=get_tsfel_features(X_train_raw,'statistical')
# Out:
# Extracted TSFEL features for window-1
# Extracted TSFEL features for window-2
# Extracted TSFEL features for window-3
# Extracted TSFEL features for window-4
# Extracted TSFEL features for window-5
# Extracted TSFEL features for window-6
# Extracted TSFEL features for window-7
# Extracted TSFEL features for window-8
# Extracted TSFEL features for window-9
# Extracted TSFEL features for window-10
# Extracted TSFEL features for window-11
# Extracted TSFEL features for window-12
# Extracted TSFEL features for window-13
# Extracted TSFEL features for window-14
# Extracted TSFEL features for window-15
# Extracted TSFEL features for window-16
# Extracted TSFEL features for window-17
# Extracted TSFEL features for window-18
# Extracted TSFEL features for window-19
# Extracted TSFEL features for window-20
# Extracted TSFEL features for window-21
# Extracted TSFEL features for window-22
# Extracted TSFEL features for window-23
# Extracted TSFEL features for window-24
# Extracted TSFEL features for window-25
# Extracted TSFEL features for window-26
# Extracted TSFEL features for window-27
# Extracted TSFEL features for window-28
# Extracted TSFEL features for window-29
# Extracted TSFEL features for window-30
# Extracted TSFEL features for window-31
# Extracted TSFEL features for window-32
# Extracted TSFEL features for window-33
# Extracted TSFEL features for window-34
# Extracted TSFEL features for window-35
# Extracted TSFEL features for window-36
# Extracted TSFEL features for window-37
# Extracted TSFEL features for window-38
# Extracted TSFEL features for window-39
# Extracted TSFEL features for window-40
# Extracted TSFEL features for window-41
# Extracted TSFEL features for window-42
# Extracted TSFEL features for window-43
# Extracted TSFEL features for window-44
# Extracted TSFEL features for window-45
# Extracted TSFEL features for window-46
# Extracted TSFEL features for window-47
# Extracted TSFEL features for window-48
# Extracted TSFEL features for window-49
# Extracted TSFEL features for window-50
# Extracted TSFEL features for window-51
# Extracted TSFEL features for window-52
# Extracted TSFEL features for window-53
# Extracted TSFEL features for window-54
# Extracted TSFEL features for window-55
# Extracted TSFEL features for window-56
# Extracted TSFEL features for window-57
# Extracted TSFEL features for window-58
# Extracted TSFEL features for window-59
# Extracted TSFEL features for window-60
# Extracted TSFEL features for window-61
# Extracted TSFEL features for window-62
# Extracted TSFEL features for window-63
# Extracted TSFEL features for window-64
# Extracted TSFEL features for window-65
# Extracted TSFEL features for window-66
# Extracted TSFEL features for window-67
# Extracted TSFEL features for window-68
# Extracted TSFEL features for window-69
# Extracted TSFEL features for window-70
# Extracted TSFEL features for window-71
# Extracted TSFEL features for window-72
# Extracted TSFEL features for window-73
# Extracted TSFEL features for window-74
# Extracted TSFEL features for window-75
# Extracted TSFEL features for window-76
# Extracted TSFEL features for window-77
# Extracted TSFEL features for window-78
# Extracted TSFEL features for window-79
# Extracted TSFEL features for window-80
# Extracted TSFEL features for window-81
# Extracted TSFEL features for window-82
# Extracted TSFEL features for window-83
# Extracted TSFEL features for window-84
# Extracted TSFEL features for window-85
# Extracted TSFEL features for window-86
# Extracted TSFEL features for window-87
# Extracted TSFEL features for window-88
# Extracted TSFEL features for window-89
# Extracted TSFEL features for window-90
# Extracted TSFEL features for window-91
# Extracted TSFEL features for window-92
# Extracted TSFEL features for window-93
# Extracted TSFEL features for window-94
# Extracted TSFEL features for window-95
# Extracted TSFEL features for window-96
# Extracted TSFEL features for window-97
# Extracted TSFEL features for window-98
# Extracted TSFEL features for window-99
# Extracted TSFEL features for window-100
# Extracted TSFEL features for window-101
# Extracted TSFEL features for window-102
# Extracted TSFEL features for window-103
# Extracted TSFEL features for window-104
# Extracted TSFEL features for window-105
# Extracted TSFEL features for window-106
# Extracted TSFEL features for window-107
# Extracted TSFEL features for window-108
# Extracted TSFEL features for window-109
# Extracted TSFEL features for window-110
# Extracted TSFEL features for window-111
# Extracted TSFEL features for window-112
# Extracted TSFEL features for window-113
# Extracted TSFEL features for window-114
# Extracted TSFEL features for window-115
# Extracted TSFEL features for window-116
# Extracted TSFEL features for window-117
# Extracted TSFEL features for window-118
# Extracted TSFEL features for window-119
# Extracted TSFEL features for window-120
# Extracted TSFEL features for window-121
# Extracted TSFEL features for window-122
# Extracted TSFEL features for window-123
# Extracted TSFEL features for window-124
# Extracted TSFEL features for window-125
# Extracted TSFEL features for window-126
# Extracted TSFEL features for window-127
# Extracted TSFEL features for window-128
# Extracted TSFEL features for window-129
# Extracted TSFEL features for window-130
# Extracted TSFEL features for window-131
# Extracted TSFEL features for window-132
# Extracted TSFEL features for window-133
# Extracted TSFEL features for window-134
# Extracted TSFEL features for window-135
# Extracted TSFEL features for window-136
# Extracted TSFEL features for window-137
# Extracted TSFEL features for window-138
# Extracted TSFEL features for window-139
# Extracted TSFEL features for window-140
# Extracted TSFEL features for window-141
# Extracted TSFEL features for window-142
# Extracted TSFEL features for window-143
# Extracted TSFEL features for window-144
# Extracted TSFEL features for window-145
# Extracted TSFEL features for window-146
# Extracted TSFEL features for window-147
# Extracted TSFEL features for window-148
# Extracted TSFEL features for window-149
# Extracted TSFEL features for window-150
# Extracted TSFEL features for window-151
# Extracted TSFEL features for window-152
# Extracted TSFEL features for window-153
# Extracted TSFEL features for window-154
# Extracted TSFEL features for window-155
# Extracted TSFEL features for window-156
# Extracted TSFEL features for window-157
# Extracted TSFEL features for window-158
# Extracted TSFEL features for window-159
# Extracted TSFEL features for window-160
# Extracted TSFEL features for window-161
# Extracted TSFEL features for window-162
# Extracted TSFEL features for window-163
# Extracted TSFEL features for window-164
# Extracted TSFEL features for window-165
# Extracted TSFEL features for window-166
# Extracted TSFEL features for window-167
# Extracted TSFEL features for window-168
# Extracted TSFEL features for window-169
# Extracted TSFEL features for window-170
# Extracted TSFEL features for window-171
# Extracted TSFEL features for window-172
# Extracted TSFEL features for window-173
# Extracted TSFEL features for window-174
# Extracted TSFEL features for window-175
# Extracted TSFEL features for window-176
# Extracted TSFEL features for window-177
# Extracted TSFEL features for window-178
# Extracted TSFEL features for window-179
# Extracted TSFEL features for window-180
# Extracted TSFEL features for window-181
# Extracted TSFEL features for window-182
# Extracted TSFEL features for window-183
# Extracted TSFEL features for window-184
# Extracted TSFEL features for window-185
# Extracted TSFEL features for window-186
# Extracted TSFEL features for window-187
# Extracted TSFEL features for window-188
# Extracted TSFEL features for window-189
# Extracted TSFEL features for window-190
# Extracted TSFEL features for window-191
# Extracted TSFEL features for window-192
# Extracted TSFEL features for window-193
# Extracted TSFEL features for window-194
# Extracted TSFEL features for window-195
# Extracted TSFEL features for window-196
# Extracted TSFEL features for window-197
# Extracted TSFEL features for window-198
# Extracted TSFEL features for window-199
# Extracted TSFEL features for window-200
# Extracted TSFEL features for window-201
# Extracted TSFEL features for window-202
# Extracted TSFEL features for window-203
# Extracted TSFEL features for window-204
# Extracted TSFEL features for window-205
# Extracted TSFEL features for window-206
# Extracted TSFEL features for window-207
# Extracted TSFEL features for window-208
# Extracted TSFEL features for window-209
# Extracted TSFEL features for window-210
# Extracted TSFEL features for window-211
# Extracted TSFEL features for window-212
# Extracted TSFEL features for window-213
# Extracted TSFEL features for window-214
# Extracted TSFEL features for window-215
# Extracted TSFEL features for window-216
# Extracted TSFEL features for window-217
# Extracted TSFEL features for window-218
# Extracted TSFEL features for window-219
# Extracted TSFEL features for window-220
# Extracted TSFEL features for window-221
# Extracted TSFEL features for window-222
# Extracted TSFEL features for window-223
# Extracted TSFEL features for window-224
# Extracted TSFEL features for window-225
# Extracted TSFEL features for window-226
# Extracted TSFEL features for window-227
# Extracted TSFEL features for window-228
# Extracted TSFEL features for window-229
# Extracted TSFEL features for window-230
# Extracted TSFEL features for window-231
# Extracted TSFEL features for window-232
# Extracted TSFEL features for window-233
# Extracted TSFEL features for window-234
# Extracted TSFEL features for window-235
# Extracted TSFEL features for window-236
# Extracted TSFEL features for window-237
# Extracted TSFEL features for window-238
# Extracted TSFEL features for window-239
# Extracted TSFEL features for window-240
# Extracted TSFEL features for window-241
# Extracted TSFEL features for window-242
# Extracted TSFEL features for window-243
# Extracted TSFEL features for window-244
# Extracted TSFEL features for window-245
# Extracted TSFEL features for window-246
# Extracted TSFEL features for window-247
# Extracted TSFEL features for window-248
# Extracted TSFEL features for window-249
# Extracted TSFEL features for window-250
# Extracted TSFEL features for window-251
# Extracted TSFEL features for window-252
# Extracted TSFEL features for window-253
# Extracted TSFEL features for window-254
# Extracted TSFEL features for window-255
# Extracted TSFEL features for window-256
# Extracted TSFEL features for window-257
# Extracted TSFEL features for window-258
# Extracted TSFEL features for window-259
# Extracted TSFEL features for window-260
# Extracted TSFEL features for window-261
# Extracted TSFEL features for window-262
# Extracted TSFEL features for window-263
# Extracted TSFEL features for window-264
# Extracted TSFEL features for window-265
# Extracted TSFEL features for window-266
# Extracted TSFEL features for window-267
# Extracted TSFEL features for window-268
# Extracted TSFEL features for window-269
# Extracted TSFEL features for window-270
# Extracted TSFEL features for window-271
# Extracted TSFEL features for window-272
# Extracted TSFEL features for window-273
# Extracted TSFEL features for window-274
# Extracted TSFEL features for window-275
# Extracted TSFEL features for window-276
# Extracted TSFEL features for window-277
# Extracted TSFEL features for window-278
# Extracted TSFEL features for window-279
# Extracted TSFEL features for window-280
# Extracted TSFEL features for window-281
# Extracted TSFEL features for window-282
# Extracted TSFEL features for window-283
# Extracted TSFEL features for window-284
# Extracted TSFEL features for window-285
# Extracted TSFEL features for window-286
# Extracted TSFEL features for window-287
# Extracted TSFEL features for window-288
# Extracted TSFEL features for window-289
# Extracted TSFEL features for window-290
# Extracted TSFEL features for window-291
# Extracted TSFEL features for window-292
# Extracted TSFEL features for window-293
# Extracted TSFEL features for window-294
# Extracted TSFEL features for window-295
# Extracted TSFEL features for window-296
# Extracted TSFEL features for window-297
# Extracted TSFEL features for window-298
# Extracted TSFEL features for window-299
# Extracted TSFEL features for window-300
# Extracted TSFEL features for window-301
# Extracted TSFEL features for window-302
# Extracted TSFEL features for window-303
# Extracted TSFEL features for window-304
# Extracted TSFEL features for window-305
# Extracted TSFEL features for window-306
# Extracted TSFEL features for window-307
# Extracted TSFEL features for window-308
# Extracted TSFEL features for window-309
# Extracted TSFEL features for window-310
# Extracted TSFEL features for window-311
# Extracted TSFEL features for window-312
# Extracted TSFEL features for window-313
# Extracted TSFEL features for window-314
# Extracted TSFEL features for window-315
# Extracted TSFEL features for window-316
# Extracted TSFEL features for window-317
# Extracted TSFEL features for window-318
# Extracted TSFEL features for window-319
# Extracted TSFEL features for window-320
# Extracted TSFEL features for window-321
# Extracted TSFEL features for window-322
# Extracted TSFEL features for window-323
# Extracted TSFEL features for window-324
# Extracted TSFEL features for window-325
# Extracted TSFEL features for window-326
# Extracted TSFEL features for window-327
# Extracted TSFEL features for window-328
# Extracted TSFEL features for window-329
# Extracted TSFEL features for window-330
# Extracted TSFEL features for window-331
# Extracted TSFEL features for window-332
# Extracted TSFEL features for window-333
# Extracted TSFEL features for window-334
# Extracted TSFEL features for window-335
# Extracted TSFEL features for window-336
# Extracted TSFEL features for window-337
# Extracted TSFEL features for window-338
# Extracted TSFEL features for window-339
# Extracted TSFEL features for window-340
# Extracted TSFEL features for window-341
# Extracted TSFEL features for window-342
# Extracted TSFEL features for window-343
# Extracted TSFEL features for window-344
# Extracted TSFEL features for window-345
# Extracted TSFEL features for window-346
# Extracted TSFEL features for window-347
# Extracted TSFEL features for window-348
# Extracted TSFEL features for window-349
# Extracted TSFEL features for window-350
# Extracted TSFEL features for window-351
# Extracted TSFEL features for window-352
# Extracted TSFEL features for window-353
# Extracted TSFEL features for window-354
# Extracted TSFEL features for window-355
# Extracted TSFEL features for window-356
# Extracted TSFEL features for window-357
# Extracted TSFEL features for window-358
# Extracted TSFEL features for window-359
# Extracted TSFEL features for window-360
# Extracted TSFEL features for window-361
# Extracted TSFEL features for window-362
# Extracted TSFEL features for window-363
# Extracted TSFEL features for window-364
# Extracted TSFEL features for window-365
# Extracted TSFEL features for window-366
# Extracted TSFEL features for window-367
# Extracted TSFEL features for window-368
# Extracted TSFEL features for window-369
# Extracted TSFEL features for window-370
# Extracted TSFEL features for window-371
# Extracted TSFEL features for window-372
# Extracted TSFEL features for window-373
# Extracted TSFEL features for window-374
# Extracted TSFEL features for window-375
# Extracted TSFEL features for window-376
# Extracted TSFEL features for window-377
# Extracted TSFEL features for window-378
# Extracted TSFEL features for window-379
# Extracted TSFEL features for window-380
# Extracted TSFEL features for window-381
# Extracted TSFEL features for window-382
# Extracted TSFEL features for window-383
# Extracted TSFEL features for window-384
# Extracted TSFEL features for window-385
# Extracted TSFEL features for window-386
# Extracted TSFEL features for window-387
# Extracted TSFEL features for window-388
# Extracted TSFEL features for window-389
# Extracted TSFEL features for window-390
# Extracted TSFEL features for window-391
# Extracted TSFEL features for window-392
# Extracted TSFEL features for window-393
# Extracted TSFEL features for window-394
# Extracted TSFEL features for window-395
# Extracted TSFEL features for window-396
# Extracted TSFEL features for window-397
# Extracted TSFEL features for window-398
# Extracted TSFEL features for window-399
# Extracted TSFEL features for window-400
# Extracted TSFEL features for window-401
# Extracted TSFEL features for window-402
# Extracted TSFEL features for window-403
# Extracted TSFEL features for window-404
# Extracted TSFEL features for window-405
# Extracted TSFEL features for window-406
# Extracted TSFEL features for window-407
# Extracted TSFEL features for window-408
# Extracted TSFEL features for window-409
# Extracted TSFEL features for window-410
# Extracted TSFEL features for window-411
# Extracted TSFEL features for window-412
# Extracted TSFEL features for window-413
# Extracted TSFEL features for window-414
# Extracted TSFEL features for window-415
# Extracted TSFEL features for window-416
# Extracted TSFEL features for window-417
# Extracted TSFEL features for window-418
# Extracted TSFEL features for window-419
# Extracted TSFEL features for window-420
# Extracted TSFEL features for window-421
# Extracted TSFEL features for window-422
# Extracted TSFEL features for window-423
# Extracted TSFEL features for window-424
# Extracted TSFEL features for window-425
# Extracted TSFEL features for window-426
# Extracted TSFEL features for window-427
# Extracted TSFEL features for window-428
# Extracted TSFEL features for window-429
# Extracted TSFEL features for window-430
# Extracted TSFEL features for window-431
# Extracted TSFEL features for window-432
# Extracted TSFEL features for window-433
# Extracted TSFEL features for window-434
# Extracted TSFEL features for window-435
# Extracted TSFEL features for window-436
# Extracted TSFEL features for window-437
# Extracted TSFEL features for window-438
# Extracted TSFEL features for window-439
# Extracted TSFEL features for window-440
# Extracted TSFEL features for window-441
# Extracted TSFEL features for window-442
# Extracted TSFEL features for window-443
# Extracted TSFEL features for window-444
# Extracted TSFEL features for window-445
# Extracted TSFEL features for window-446
# Extracted TSFEL features for window-447
# Extracted TSFEL features for window-448
# Extracted TSFEL features for window-449
# Extracted TSFEL features for window-450
# Extracted TSFEL features for window-451
# Extracted TSFEL features for window-452
# Extracted TSFEL features for window-453
# Extracted TSFEL features for window-454
# Extracted TSFEL features for window-455
# Extracted TSFEL features for window-456
# Extracted TSFEL features for window-457
# Extracted TSFEL features for window-458
# Extracted TSFEL features for window-459
# Extracted TSFEL features for window-460
# Extracted TSFEL features for window-461
# Extracted TSFEL features for window-462
# Extracted TSFEL features for window-463
# Extracted TSFEL features for window-464
# Extracted TSFEL features for window-465
# Extracted TSFEL features for window-466
# Extracted TSFEL features for window-467
# Extracted TSFEL features for window-468
# Extracted TSFEL features for window-469
# Extracted TSFEL features for window-470
# Extracted TSFEL features for window-471
# Extracted TSFEL features for window-472
# Extracted TSFEL features for window-473
# Extracted TSFEL features for window-474
# Extracted TSFEL features for window-475
# Extracted TSFEL features for window-476
# Extracted TSFEL features for window-477
# Extracted TSFEL features for window-478
# Extracted TSFEL features for window-479
# Extracted TSFEL features for window-480
# Extracted TSFEL features for window-481
# Extracted TSFEL features for window-482
# Extracted TSFEL features for window-483
# Extracted TSFEL features for window-484
# Extracted TSFEL features for window-485
# Extracted TSFEL features for window-486
# Extracted TSFEL features for window-487
# Extracted TSFEL features for window-488
# Extracted TSFEL features for window-489
# Extracted TSFEL features for window-490
# Extracted TSFEL features for window-491
# Extracted TSFEL features for window-492
# Extracted TSFEL features for window-493
# Extracted TSFEL features for window-494
# Extracted TSFEL features for window-495
# Extracted TSFEL features for window-496
# Extracted TSFEL features for window-497
# Extracted TSFEL features for window-498
# Extracted TSFEL features for window-499
# Extracted TSFEL features for window-500
# Extracted TSFEL features for window-501
# Extracted TSFEL features for window-502
# Extracted TSFEL features for window-503
# Extracted TSFEL features for window-504
# Extracted TSFEL features for window-505
# Extracted TSFEL features for window-506
# Extracted TSFEL features for window-507
# Extracted TSFEL features for window-508
# Extracted TSFEL features for window-509
# Extracted TSFEL features for window-510
# Extracted TSFEL features for window-511
# Extracted TSFEL features for window-512
# Extracted TSFEL features for window-513
# Extracted TSFEL features for window-514
# Extracted TSFEL features for window-515
# Extracted TSFEL features for window-516
# Extracted TSFEL features for window-517
# Extracted TSFEL features for window-518
# Extracted TSFEL features for window-519
# Extracted TSFEL features for window-520
# Extracted TSFEL features for window-521
# Extracted TSFEL features for window-522
# Extracted TSFEL features for window-523
# Extracted TSFEL features for window-524
# Extracted TSFEL features for window-525
# Extracted TSFEL features for window-526
# Extracted TSFEL features for window-527
# Extracted TSFEL features for window-528
# Extracted TSFEL features for window-529
# Extracted TSFEL features for window-530
# Extracted TSFEL features for window-531
# Extracted TSFEL features for window-532
# Extracted TSFEL features for window-533
# Extracted TSFEL features for window-534
# Extracted TSFEL features for window-535
# Extracted TSFEL features for window-536
# Extracted TSFEL features for window-537
# Extracted TSFEL features for window-538
# Extracted TSFEL features for window-539
# Extracted TSFEL features for window-540
# Extracted TSFEL features for window-541
# Extracted TSFEL features for window-542
# Extracted TSFEL features for window-543
# Extracted TSFEL features for window-544
# Extracted TSFEL features for window-545
# Extracted TSFEL features for window-546
# Extracted TSFEL features for window-547
# Extracted TSFEL features for window-548
# Extracted TSFEL features for window-549
# Extracted TSFEL features for window-550
# Extracted TSFEL features for window-551
# Extracted TSFEL features for window-552
# Extracted TSFEL features for window-553
# Extracted TSFEL features for window-554
# Extracted TSFEL features for window-555
# Extracted TSFEL features for window-556
# Extracted TSFEL features for window-557
# Extracted TSFEL features for window-558
# Extracted TSFEL features for window-559
# Extracted TSFEL features for window-560
# Extracted TSFEL features for window-561
# Extracted TSFEL features for window-562
# Extracted TSFEL features for window-563
# Extracted TSFEL features for window-564
# Extracted TSFEL features for window-565
# Extracted TSFEL features for window-566
# Extracted TSFEL features for window-567
# Extracted TSFEL features for window-568
# Extracted TSFEL features for window-569
# Extracted TSFEL features for window-570
# Extracted TSFEL features for window-571
# Extracted TSFEL features for window-572
# Extracted TSFEL features for window-573
# Extracted TSFEL features for window-574
# Extracted TSFEL features for window-575
# Extracted TSFEL features for window-576
# Extracted TSFEL features for window-577
# Extracted TSFEL features for window-578
# Extracted TSFEL features for window-579
# Extracted TSFEL features for window-580
# Extracted TSFEL features for window-581
# Extracted TSFEL features for window-582
# Extracted TSFEL features for window-583
# Extracted TSFEL features for window-584
# Extracted TSFEL features for window-585
# Extracted TSFEL features for window-586
# Extracted TSFEL features for window-587
# Extracted TSFEL features for window-588
# Extracted TSFEL features for window-589
# Extracted TSFEL features for window-590
# Extracted TSFEL features for window-591
# Extracted TSFEL features for window-592
# Extracted TSFEL features for window-593
# Extracted TSFEL features for window-594
# Extracted TSFEL features for window-595
# Extracted TSFEL features for window-596
# Extracted TSFEL features for window-597
# Extracted TSFEL features for window-598
# Extracted TSFEL features for window-599
# Extracted TSFEL features for window-600
# Extracted TSFEL features for window-601
# Extracted TSFEL features for window-602
# Extracted TSFEL features for window-603
# Extracted TSFEL features for window-604
# Extracted TSFEL features for window-605
# Extracted TSFEL features for window-606
# Extracted TSFEL features for window-607
# Extracted TSFEL features for window-608
# Extracted TSFEL features for window-609
# Extracted TSFEL features for window-610
# Extracted TSFEL features for window-611
# Extracted TSFEL features for window-612
# Extracted TSFEL features for window-613
# Extracted TSFEL features for window-614
# Extracted TSFEL features for window-615
# Extracted TSFEL features for window-616
# Extracted TSFEL features for window-617
# Extracted TSFEL features for window-618
# Extracted TSFEL features for window-619
# Extracted TSFEL features for window-620
# Extracted TSFEL features for window-621
# Extracted TSFEL features for window-622
# Extracted TSFEL features for window-623
# Extracted TSFEL features for window-624
# Extracted TSFEL features for window-625
# Extracted TSFEL features for window-626
# Extracted TSFEL features for window-627
# Extracted TSFEL features for window-628
# Extracted TSFEL features for window-629
# Extracted TSFEL features for window-630
# Extracted TSFEL features for window-631
# Extracted TSFEL features for window-632
# Extracted TSFEL features for window-633
# Extracted TSFEL features for window-634
# Extracted TSFEL features for window-635
# Extracted TSFEL features for window-636
# Extracted TSFEL features for window-637
# Extracted TSFEL features for window-638
# Extracted TSFEL features for window-639
# Extracted TSFEL features for window-640
# Extracted TSFEL features for window-641
# Extracted TSFEL features for window-642
# Extracted TSFEL features for window-643
# Extracted TSFEL features for window-644
# Extracted TSFEL features for window-645
# Extracted TSFEL features for window-646
# Extracted TSFEL features for window-647
# Extracted TSFEL features for window-648
# Extracted TSFEL features for window-649
# Extracted TSFEL features for window-650
# Extracted TSFEL features for window-651
# Extracted TSFEL features for window-652
# Extracted TSFEL features for window-653
# Extracted TSFEL features for window-654
# Extracted TSFEL features for window-655
# Extracted TSFEL features for window-656
# Extracted TSFEL features for window-657
# Extracted TSFEL features for window-658
# Extracted TSFEL features for window-659
# Extracted TSFEL features for window-660
# Extracted TSFEL features for window-661
# Extracted TSFEL features for window-662
# Extracted TSFEL features for window-663
# Extracted TSFEL features for window-664
# Extracted TSFEL features for window-665
# Extracted TSFEL features for window-666
# Extracted TSFEL features for window-667
# Extracted TSFEL features for window-668
# Extracted TSFEL features for window-669
# Extracted TSFEL features for window-670
# Extracted TSFEL features for window-671
# Extracted TSFEL features for window-672
# Extracted TSFEL features for window-673
# Extracted TSFEL features for window-674
# Extracted TSFEL features for window-675
# Extracted TSFEL features for window-676
# Extracted TSFEL features for window-677
# Extracted TSFEL features for window-678
# Extracted TSFEL features for window-679
# Extracted TSFEL features for window-680
# Extracted TSFEL features for window-681
# Extracted TSFEL features for window-682
# Extracted TSFEL features for window-683
# Extracted TSFEL features for window-684
# Extracted TSFEL features for window-685
# Extracted TSFEL features for window-686
# Extracted TSFEL features for window-687
# Extracted TSFEL features for window-688
# Extracted TSFEL features for window-689
# Extracted TSFEL features for window-690
# Extracted TSFEL features for window-691
# Extracted TSFEL features for window-692
# Extracted TSFEL features for window-693
# Extracted TSFEL features for window-694
# Extracted TSFEL features for window-695
# Extracted TSFEL features for window-696
# Extracted TSFEL features for window-697
# Extracted TSFEL features for window-698
# Extracted TSFEL features for window-699
# Extracted TSFEL features for window-700
# Extracted TSFEL features for window-701
# Extracted TSFEL features for window-702
# Extracted TSFEL features for window-703
# Extracted TSFEL features for window-704
# Extracted TSFEL features for window-705
# Extracted TSFEL features for window-706
# Extracted TSFEL features for window-707
# Extracted TSFEL features for window-708
# Extracted TSFEL features for window-709
# Extracted TSFEL features for window-710
# Extracted TSFEL features for window-711
# Extracted TSFEL features for window-712
# Extracted TSFEL features for window-713
# Extracted TSFEL features for window-714
# Extracted TSFEL features for window-715
# Extracted TSFEL features for window-716
# Extracted TSFEL features for window-717
# Extracted TSFEL features for window-718
# Extracted TSFEL features for window-719
# Extracted TSFEL features for window-720
# Extracted TSFEL features for window-721
# Extracted TSFEL features for window-722
# Extracted TSFEL features for window-723
# Extracted TSFEL features for window-724
# Extracted TSFEL features for window-725
# Extracted TSFEL features for window-726
# Extracted TSFEL features for window-727
# Extracted TSFEL features for window-728
# Extracted TSFEL features for window-729
# Extracted TSFEL features for window-730
# Extracted TSFEL features for window-731
# Extracted TSFEL features for window-732
# Extracted TSFEL features for window-733
# Extracted TSFEL features for window-734
# Extracted TSFEL features for window-735
# Extracted TSFEL features for window-736
# Extracted TSFEL features for window-737
# Extracted TSFEL features for window-738
# Extracted TSFEL features for window-739
# Extracted TSFEL features for window-740
# Extracted TSFEL features for window-741
# Extracted TSFEL features for window-742
# Extracted TSFEL features for window-743
# Extracted TSFEL features for window-744
# Extracted TSFEL features for window-745
# Extracted TSFEL features for window-746
# Extracted TSFEL features for window-747
# Extracted TSFEL features for window-748
# Extracted TSFEL features for window-749
# Extracted TSFEL features for window-750
# Extracted TSFEL features for window-751
# Extracted TSFEL features for window-752
# Extracted TSFEL features for window-753
# Extracted TSFEL features for window-754
# Extracted TSFEL features for window-755
# Extracted TSFEL features for window-756
# Extracted TSFEL features for window-757
# Extracted TSFEL features for window-758
# Extracted TSFEL features for window-759
# Extracted TSFEL features for window-760
# Extracted TSFEL features for window-761
# Extracted TSFEL features for window-762
# Extracted TSFEL features for window-763
# Extracted TSFEL features for window-764
# Extracted TSFEL features for window-765
# Extracted TSFEL features for window-766
# Extracted TSFEL features for window-767
# Extracted TSFEL features for window-768
# Extracted TSFEL features for window-769
# Extracted TSFEL features for window-770
# Extracted TSFEL features for window-771
# Extracted TSFEL features for window-772
# Extracted TSFEL features for window-773
# Extracted TSFEL features for window-774
# Extracted TSFEL features for window-775
# Extracted TSFEL features for window-776
# Extracted TSFEL features for window-777
# Extracted TSFEL features for window-778
# Extracted TSFEL features for window-779
# Extracted TSFEL features for window-780
# Extracted TSFEL features for window-781
# Extracted TSFEL features for window-782
# Extracted TSFEL features for window-783
# Extracted TSFEL features for window-784
# Extracted TSFEL features for window-785
# Extracted TSFEL features for window-786
# Extracted TSFEL features for window-787
# Extracted TSFEL features for window-788
# Extracted TSFEL features for window-789
# Extracted TSFEL features for window-790
# Extracted TSFEL features for window-791
# Extracted TSFEL features for window-792
# Extracted TSFEL features for window-793
# Extracted TSFEL features for window-794
# Extracted TSFEL features for window-795
# Extracted TSFEL features for window-796
# Extracted TSFEL features for window-797
# Extracted TSFEL features for window-798
# Extracted TSFEL features for window-799
# Extracted TSFEL features for window-800
# Extracted TSFEL features for window-801
# Extracted TSFEL features for window-802
# Extracted TSFEL features for window-803
# Extracted TSFEL features for window-804
# Extracted TSFEL features for window-805
# Extracted TSFEL features for window-806
# Extracted TSFEL features for window-807
# Extracted TSFEL features for window-808
# Extracted TSFEL features for window-809
# Extracted TSFEL features for window-810
# Extracted TSFEL features for window-811
# Extracted TSFEL features for window-812
# Extracted TSFEL features for window-813
# Extracted TSFEL features for window-814
# Extracted TSFEL features for window-815
# Extracted TSFEL features for window-816
# Extracted TSFEL features for window-817
# Extracted TSFEL features for window-818
# Extracted TSFEL features for window-819
# Extracted TSFEL features for window-820
# Extracted TSFEL features for window-821
# Extracted TSFEL features for window-822
# Extracted TSFEL features for window-823
# Extracted TSFEL features for window-824
# Extracted TSFEL features for window-825
# Extracted TSFEL features for window-826
# Extracted TSFEL features for window-827
# Extracted TSFEL features for window-828
# Extracted TSFEL features for window-829
# Extracted TSFEL features for window-830
# Extracted TSFEL features for window-831
# Extracted TSFEL features for window-832
# Extracted TSFEL features for window-833
# Extracted TSFEL features for window-834
# Extracted TSFEL features for window-835
# Extracted TSFEL features for window-836
# Extracted TSFEL features for window-837
# Extracted TSFEL features for window-838
# Extracted TSFEL features for window-839
# Extracted TSFEL features for window-840
# Extracted TSFEL features for window-841
# Extracted TSFEL features for window-842
# Extracted TSFEL features for window-843
# Extracted TSFEL features for window-844
# Extracted TSFEL features for window-845
# Extracted TSFEL features for window-846
# Extracted TSFEL features for window-847
# Extracted TSFEL features for window-848
# Extracted TSFEL features for window-849
# Extracted TSFEL features for window-850
# Extracted TSFEL features for window-851
# Extracted TSFEL features for window-852
# Extracted TSFEL features for window-853
# Extracted TSFEL features for window-854
# Extracted TSFEL features for window-855
# Extracted TSFEL features for window-856
# Extracted TSFEL features for window-857
# Extracted TSFEL features for window-858
# Extracted TSFEL features for window-859
# Extracted TSFEL features for window-860
# Extracted TSFEL features for window-861
# Extracted TSFEL features for window-862
# Extracted TSFEL features for window-863
# Extracted TSFEL features for window-864
# Extracted TSFEL features for window-865
# Extracted TSFEL features for window-866
# Extracted TSFEL features for window-867
# Extracted TSFEL features for window-868
# Extracted TSFEL features for window-869
# Extracted TSFEL features for window-870
# Extracted TSFEL features for window-871
# Extracted TSFEL features for window-872
# Extracted TSFEL features for window-873
# Extracted TSFEL features for window-874
# Extracted TSFEL features for window-875
# Extracted TSFEL features for window-876
# Extracted TSFEL features for window-877
# Extracted TSFEL features for window-878
# Extracted TSFEL features for window-879
# Extracted TSFEL features for window-880
# Extracted TSFEL features for window-881
# Extracted TSFEL features for window-882
# Extracted TSFEL features for window-883
# Extracted TSFEL features for window-884
# Extracted TSFEL features for window-885
# Extracted TSFEL features for window-886
# Extracted TSFEL features for window-887
# Extracted TSFEL features for window-888
# Extracted TSFEL features for window-889
# Extracted TSFEL features for window-890
# Extracted TSFEL features for window-891
# Extracted TSFEL features for window-892
# Extracted TSFEL features for window-893
# Extracted TSFEL features for window-894
# Extracted TSFEL features for window-895
# Extracted TSFEL features for window-896
# Extracted TSFEL features for window-897
# Extracted TSFEL features for window-898
# Extracted TSFEL features for window-899
# Extracted TSFEL features for window-900
# Extracted TSFEL features for window-901
# Extracted TSFEL features for window-902
# Extracted TSFEL features for window-903
# Extracted TSFEL features for window-904
# Extracted TSFEL features for window-905
# Extracted TSFEL features for window-906
# Extracted TSFEL features for window-907
# Extracted TSFEL features for window-908
# Extracted TSFEL features for window-909
# Extracted TSFEL features for window-910
# Extracted TSFEL features for window-911
# Extracted TSFEL features for window-912
# Extracted TSFEL features for window-913
# Extracted TSFEL features for window-914
# Extracted TSFEL features for window-915
# Extracted TSFEL features for window-916
# Extracted TSFEL features for window-917
# Extracted TSFEL features for window-918
# Extracted TSFEL features for window-919
# Extracted TSFEL features for window-920
# Extracted TSFEL features for window-921
# Extracted TSFEL features for window-922
# Extracted TSFEL features for window-923
# Extracted TSFEL features for window-924
# Extracted TSFEL features for window-925
# Extracted TSFEL features for window-926
# Extracted TSFEL features for window-927
# Extracted TSFEL features for window-928
# Extracted TSFEL features for window-929
# Extracted TSFEL features for window-930
# Extracted TSFEL features for window-931
# Extracted TSFEL features for window-932
# Extracted TSFEL features for window-933
# Extracted TSFEL features for window-934
# Extracted TSFEL features for window-935
# Extracted TSFEL features for window-936
# Extracted TSFEL features for window-937
# Extracted TSFEL features for window-938
# Extracted TSFEL features for window-939
# Extracted TSFEL features for window-940
# Extracted TSFEL features for window-941
# Extracted TSFEL features for window-942
# Extracted TSFEL features for window-943
# Extracted TSFEL features for window-944
# Extracted TSFEL features for window-945
# Extracted TSFEL features for window-946
# Extracted TSFEL features for window-947
# Extracted TSFEL features for window-948
# Extracted TSFEL features for window-949
# Extracted TSFEL features for window-950
# Extracted TSFEL features for window-951
# Extracted TSFEL features for window-952
# Extracted TSFEL features for window-953
# Extracted TSFEL features for window-954
# Extracted TSFEL features for window-955
# Extracted TSFEL features for window-956
# Extracted TSFEL features for window-957
# Extracted TSFEL features for window-958
# Extracted TSFEL features for window-959
# Extracted TSFEL features for window-960
# Extracted TSFEL features for window-961
# Extracted TSFEL features for window-962
# Extracted TSFEL features for window-963
# Extracted TSFEL features for window-964
# Extracted TSFEL features for window-965
# Extracted TSFEL features for window-966
# Extracted TSFEL features for window-967
# Extracted TSFEL features for window-968
# Extracted TSFEL features for window-969
# Extracted TSFEL features for window-970
# Extracted TSFEL features for window-971
# Extracted TSFEL features for window-972
# Extracted TSFEL features for window-973
# Extracted TSFEL features for window-974
# Extracted TSFEL features for window-975
# Extracted TSFEL features for window-976
# Extracted TSFEL features for window-977
# Extracted TSFEL features for window-978
# Extracted TSFEL features for window-979
# Extracted TSFEL features for window-980
# Extracted TSFEL features for window-981
# Extracted TSFEL features for window-982
# Extracted TSFEL features for window-983
# Extracted TSFEL features for window-984
# Extracted TSFEL features for window-985
# Extracted TSFEL features for window-986
# Extracted TSFEL features for window-987
# Extracted TSFEL features for window-988
# Extracted TSFEL features for window-989
# Extracted TSFEL features for window-990
# Extracted TSFEL features for window-991
# Extracted TSFEL features for window-992
# Extracted TSFEL features for window-993
# Extracted TSFEL features for window-994
# Extracted TSFEL features for window-995
# Extracted TSFEL features for window-996
# Extracted TSFEL features for window-997
# Extracted TSFEL features for window-998
# Extracted TSFEL features for window-999
# Extracted TSFEL features for window-1000
# Extracted TSFEL features for window-1001
# Extracted TSFEL features for window-1002
# Extracted TSFEL features for window-1003
# Extracted TSFEL features for window-1004
# Extracted TSFEL features for window-1005
# Extracted TSFEL features for window-1006
# Extracted TSFEL features for window-1007
# Extracted TSFEL features for window-1008
# Extracted TSFEL features for window-1009
# Extracted TSFEL features for window-1010
# Extracted TSFEL features for window-1011
# Extracted TSFEL features for window-1012
# Extracted TSFEL features for window-1013
# Extracted TSFEL features for window-1014
# Extracted TSFEL features for window-1015
# Extracted TSFEL features for window-1016
# Extracted TSFEL features for window-1017
# Extracted TSFEL features for window-1018
# Extracted TSFEL features for window-1019
# Extracted TSFEL features for window-1020
# Extracted TSFEL features for window-1021
# Extracted TSFEL features for window-1022
# Extracted TSFEL features for window-1023
# Extracted TSFEL features for window-1024
# Extracted TSFEL features for window-1025
# Extracted TSFEL features for window-1026
# Extracted TSFEL features for window-1027
# Extracted TSFEL features for window-1028
# Extracted TSFEL features for window-1029
# Extracted TSFEL features for window-1030
# Extracted TSFEL features for window-1031
# Extracted TSFEL features for window-1032
# Extracted TSFEL features for window-1033
# Extracted TSFEL features for window-1034
# Extracted TSFEL features for window-1035
# Extracted TSFEL features for window-1036
# Extracted TSFEL features for window-1037
# Extracted TSFEL features for window-1038
# Extracted TSFEL features for window-1039
# Extracted TSFEL features for window-1040
# Extracted TSFEL features for window-1041
# Extracted TSFEL features for window-1042
# Extracted TSFEL features for window-1043
# Extracted TSFEL features for window-1044
# Extracted TSFEL features for window-1045
# Extracted TSFEL features for window-1046
# Extracted TSFEL features for window-1047
# Extracted TSFEL features for window-1048
# Extracted TSFEL features for window-1049
# Extracted TSFEL features for window-1050
# Extracted TSFEL features for window-1051
# Extracted TSFEL features for window-1052
# Extracted TSFEL features for window-1053
# Extracted TSFEL features for window-1054
# Extracted TSFEL features for window-1055
# Extracted TSFEL features for window-1056
# Extracted TSFEL features for window-1057
# Extracted TSFEL features for window-1058
# Extracted TSFEL features for window-1059
# Extracted TSFEL features for window-1060
# Extracted TSFEL features for window-1061
# Extracted TSFEL features for window-1062
# Extracted TSFEL features for window-1063
# Extracted TSFEL features for window-1064
# Extracted TSFEL features for window-1065
# Extracted TSFEL features for window-1066
# Extracted TSFEL features for window-1067
# Extracted TSFEL features for window-1068
# Extracted TSFEL features for window-1069
# Extracted TSFEL features for window-1070
# Extracted TSFEL features for window-1071
# Extracted TSFEL features for window-1072
# Extracted TSFEL features for window-1073
# Extracted TSFEL features for window-1074
# Extracted TSFEL features for window-1075
# Extracted TSFEL features for window-1076
# Extracted TSFEL features for window-1077
# Extracted TSFEL features for window-1078
# Extracted TSFEL features for window-1079
# Extracted TSFEL features for window-1080
# Extracted TSFEL features for window-1081
# Extracted TSFEL features for window-1082
# Extracted TSFEL features for window-1083
# Extracted TSFEL features for window-1084
# Extracted TSFEL features for window-1085
# Extracted TSFEL features for window-1086
# Extracted TSFEL features for window-1087
# Extracted TSFEL features for window-1088
# Extracted TSFEL features for window-1089
# Extracted TSFEL features for window-1090
# Extracted TSFEL features for window-1091
# Extracted TSFEL features for window-1092
# Extracted TSFEL features for window-1093
# Extracted TSFEL features for window-1094
# Extracted TSFEL features for window-1095
# Extracted TSFEL features for window-1096
# Extracted TSFEL features for window-1097
# Extracted TSFEL features for window-1098
# Extracted TSFEL features for window-1099
# Extracted TSFEL features for window-1100
# Extracted TSFEL features for window-1101
# Extracted TSFEL features for window-1102
# Extracted TSFEL features for window-1103
# Extracted TSFEL features for window-1104
# Extracted TSFEL features for window-1105
# Extracted TSFEL features for window-1106
# Extracted TSFEL features for window-1107
# Extracted TSFEL features for window-1108
# Extracted TSFEL features for window-1109
# Extracted TSFEL features for window-1110
# Extracted TSFEL features for window-1111
# Extracted TSFEL features for window-1112
# Extracted TSFEL features for window-1113
# Extracted TSFEL features for window-1114
# Extracted TSFEL features for window-1115
# Extracted TSFEL features for window-1116
# Extracted TSFEL features for window-1117
# Extracted TSFEL features for window-1118
# Extracted TSFEL features for window-1119
# Extracted TSFEL features for window-1120
# Extracted TSFEL features for window-1121
# Extracted TSFEL features for window-1122
# Extracted TSFEL features for window-1123
# Extracted TSFEL features for window-1124
# Extracted TSFEL features for window-1125
# Extracted TSFEL features for window-1126
# Extracted TSFEL features for window-1127
# Extracted TSFEL features for window-1128
# Extracted TSFEL features for window-1129
# Extracted TSFEL features for window-1130
# Extracted TSFEL features for window-1131
# Extracted TSFEL features for window-1132
# Extracted TSFEL features for window-1133
# Extracted TSFEL features for window-1134
# Extracted TSFEL features for window-1135
# Extracted TSFEL features for window-1136
# Extracted TSFEL features for window-1137
# Extracted TSFEL features for window-1138
# Extracted TSFEL features for window-1139
# Extracted TSFEL features for window-1140
# Extracted TSFEL features for window-1141
# Extracted TSFEL features for window-1142
# Extracted TSFEL features for window-1143
# Extracted TSFEL features for window-1144
# Extracted TSFEL features for window-1145
# Extracted TSFEL features for window-1146
# Extracted TSFEL features for window-1147
# Extracted TSFEL features for window-1148
# Extracted TSFEL features for window-1149
# Extracted TSFEL features for window-1150
# Extracted TSFEL features for window-1151
# Extracted TSFEL features for window-1152
# Extracted TSFEL features for window-1153
# Extracted TSFEL features for window-1154
# Extracted TSFEL features for window-1155
# Extracted TSFEL features for window-1156
# Extracted TSFEL features for window-1157
# Extracted TSFEL features for window-1158
# Extracted TSFEL features for window-1159
# Extracted TSFEL features for window-1160
# Extracted TSFEL features for window-1161
# Extracted TSFEL features for window-1162
# Extracted TSFEL features for window-1163
# Extracted TSFEL features for window-1164
# Extracted TSFEL features for window-1165
# Extracted TSFEL features for window-1166
# Extracted TSFEL features for window-1167
# Extracted TSFEL features for window-1168
# Extracted TSFEL features for window-1169
# Extracted TSFEL features for window-1170
# Extracted TSFEL features for window-1171
# Extracted TSFEL features for window-1172
# Extracted TSFEL features for window-1173
# Extracted TSFEL features for window-1174
# Extracted TSFEL features for window-1175
# Extracted TSFEL features for window-1176
# Extracted TSFEL features for window-1177
# Extracted TSFEL features for window-1178
# Extracted TSFEL features for window-1179
# Extracted TSFEL features for window-1180
# Extracted TSFEL features for window-1181
# Extracted TSFEL features for window-1182
# Extracted TSFEL features for window-1183
# Extracted TSFEL features for window-1184
# Extracted TSFEL features for window-1185
# Extracted TSFEL features for window-1186
# Extracted TSFEL features for window-1187
# Extracted TSFEL features for window-1188
# Extracted TSFEL features for window-1189
# Extracted TSFEL features for window-1190
# Extracted TSFEL features for window-1191
# Extracted TSFEL features for window-1192
# Extracted TSFEL features for window-1193
# Extracted TSFEL features for window-1194
# Extracted TSFEL features for window-1195
# Extracted TSFEL features for window-1196
# Extracted TSFEL features for window-1197
# ...
# Extracted TSFEL features for window-6963
# Extracted TSFEL features for window-6964
# Extracted TSFEL features for window-6965
# Extracted TSFEL features for window-6966
# Extracted TSFEL features for window-6967
# Extracted TSFEL features for window-6968
# Extracted TSFEL features for window-6969
# Extracted TSFEL features for window-6970
# Extracted TSFEL features for window-6971
# Extracted TSFEL features for window-6972
# Extracted TSFEL features for window-6973
# Extracted TSFEL features for window-6974
# Extracted TSFEL features for window-6975
# Extracted TSFEL features for window-6976
# Extracted TSFEL features for window-6977
# Extracted TSFEL features for window-6978
# Extracted TSFEL features for window-6979
# Extracted TSFEL features for window-6980
# Extracted TSFEL features for window-6981
# Extracted TSFEL features for window-6982
# Extracted TSFEL features for window-6983
# Extracted TSFEL features for window-6984
# Extracted TSFEL features for window-6985
# Extracted TSFEL features for window-6986
# Extracted TSFEL features for window-6987
# Extracted TSFEL features for window-6988
# Extracted TSFEL features for window-6989
# Extracted TSFEL features for window-6990
# Extracted TSFEL features for window-6991
# Extracted TSFEL features for window-6992
# Extracted TSFEL features for window-6993
# Extracted TSFEL features for window-6994
# Extracted TSFEL features for window-6995
# Extracted TSFEL features for window-6996
# Extracted TSFEL features for window-6997
# Extracted TSFEL features for window-6998
# Extracted TSFEL features for window-6999
# Extracted TSFEL features for window-7000
# Extracted TSFEL features for window-7001
# Extracted TSFEL features for window-7002
# Extracted TSFEL features for window-7003
# Extracted TSFEL features for window-7004
# Extracted TSFEL features for window-7005
# Extracted TSFEL features for window-7006
# Extracted TSFEL features for window-7007
# Extracted TSFEL features for window-7008
# Extracted TSFEL features for window-7009
# Extracted TSFEL features for window-7010
# Extracted TSFEL features for window-7011
# Extracted TSFEL features for window-7012
# Extracted TSFEL features for window-7013
# Extracted TSFEL features for window-7014
# Extracted TSFEL features for window-7015
# Extracted TSFEL features for window-7016
# Extracted TSFEL features for window-7017
# Extracted TSFEL features for window-7018
# Extracted TSFEL features for window-7019
# Extracted TSFEL features for window-7020
# Extracted TSFEL features for window-7021
# Extracted TSFEL features for window-7022
# Extracted TSFEL features for window-7023
# Extracted TSFEL features for window-7024
# Extracted TSFEL features for window-7025
# Extracted TSFEL features for window-7026
# Extracted TSFEL features for window-7027
# Extracted TSFEL features for window-7028
# Extracted TSFEL features for window-7029
# Extracted TSFEL features for window-7030
# Extracted TSFEL features for window-7031
# Extracted TSFEL features for window-7032
# Extracted TSFEL features for window-7033
# Extracted TSFEL features for window-7034
# Extracted TSFEL features for window-7035
# Extracted TSFEL features for window-7036
# Extracted TSFEL features for window-7037
# Extracted TSFEL features for window-7038
# Extracted TSFEL features for window-7039
# Extracted TSFEL features for window-7040
# Extracted TSFEL features for window-7041
# Extracted TSFEL features for window-7042
# Extracted TSFEL features for window-7043
# Extracted TSFEL features for window-7044
# Extracted TSFEL features for window-7045
# Extracted TSFEL features for window-7046
# Extracted TSFEL features for window-7047
# Extracted TSFEL features for window-7048
# Extracted TSFEL features for window-7049
# Extracted TSFEL features for window-7050
# Extracted TSFEL features for window-7051
# Extracted TSFEL features for window-7052
# Extracted TSFEL features for window-7053
# Extracted TSFEL features for window-7054
# Extracted TSFEL features for window-7055
# Extracted TSFEL features for window-7056
# Extracted TSFEL features for window-7057
# Extracted TSFEL features for window-7058
# Extracted TSFEL features for window-7059
# Extracted TSFEL features for window-7060
# Extracted TSFEL features for window-7061
# Extracted TSFEL features for window-7062
# Extracted TSFEL features for window-7063
# Extracted TSFEL features for window-7064
# Extracted TSFEL features for window-7065
# Extracted TSFEL features for window-7066
# Extracted TSFEL features for window-7067
# Extracted TSFEL features for window-7068
# Extracted TSFEL features for window-7069
# Extracted TSFEL features for window-7070
# Extracted TSFEL features for window-7071
# Extracted TSFEL features for window-7072
# Extracted TSFEL features for window-7073
# Extracted TSFEL features for window-7074
# Extracted TSFEL features for window-7075
# Extracted TSFEL features for window-7076
# Extracted TSFEL features for window-7077
# Extracted TSFEL features for window-7078
# Extracted TSFEL features for window-7079
# Extracted TSFEL features for window-7080
# Extracted TSFEL features for window-7081
# Extracted TSFEL features for window-7082
# Extracted TSFEL features for window-7083
# Extracted TSFEL features for window-7084
# Extracted TSFEL features for window-7085
# Extracted TSFEL features for window-7086
# Extracted TSFEL features for window-7087
# Extracted TSFEL features for window-7088
# Extracted TSFEL features for window-7089
# Extracted TSFEL features for window-7090
# Extracted TSFEL features for window-7091
# Extracted TSFEL features for window-7092
# Extracted TSFEL features for window-7093
# Extracted TSFEL features for window-7094
# Extracted TSFEL features for window-7095
# Extracted TSFEL features for window-7096
# Extracted TSFEL features for window-7097
# Extracted TSFEL features for window-7098
# Extracted TSFEL features for window-7099
# Extracted TSFEL features for window-7100
# Extracted TSFEL features for window-7101
# Extracted TSFEL features for window-7102
# Extracted TSFEL features for window-7103
# Extracted TSFEL features for window-7104
# Extracted TSFEL features for window-7105
# Extracted TSFEL features for window-7106
# Extracted TSFEL features for window-7107
# Extracted TSFEL features for window-7108
# Extracted TSFEL features for window-7109
# Extracted TSFEL features for window-7110
# Extracted TSFEL features for window-7111
# Extracted TSFEL features for window-7112
# Extracted TSFEL features for window-7113
# Extracted TSFEL features for window-7114
# Extracted TSFEL features for window-7115
# Extracted TSFEL features for window-7116
# Extracted TSFEL features for window-7117
# Extracted TSFEL features for window-7118
# Extracted TSFEL features for window-7119
# Extracted TSFEL features for window-7120
# Extracted TSFEL features for window-7121
# Extracted TSFEL features for window-7122
# Extracted TSFEL features for window-7123
# Extracted TSFEL features for window-7124
# Extracted TSFEL features for window-7125
# Extracted TSFEL features for window-7126
# Extracted TSFEL features for window-7127
# Extracted TSFEL features for window-7128
# Extracted TSFEL features for window-7129
# Extracted TSFEL features for window-7130
# Extracted TSFEL features for window-7131
# Extracted TSFEL features for window-7132
# Extracted TSFEL features for window-7133
# Extracted TSFEL features for window-7134
# Extracted TSFEL features for window-7135
# Extracted TSFEL features for window-7136
# Extracted TSFEL features for window-7137
# Extracted TSFEL features for window-7138
# Extracted TSFEL features for window-7139
# Extracted TSFEL features for window-7140
# Extracted TSFEL features for window-7141
# Extracted TSFEL features for window-7142
# Extracted TSFEL features for window-7143
# Extracted TSFEL features for window-7144
# Extracted TSFEL features for window-7145
# Extracted TSFEL features for window-7146
# Extracted TSFEL features for window-7147
# Extracted TSFEL features for window-7148
# Extracted TSFEL features for window-7149
# Extracted TSFEL features for window-7150
# Extracted TSFEL features for window-7151
# Extracted TSFEL features for window-7152
# Extracted TSFEL features for window-7153
# Extracted TSFEL features for window-7154
# Extracted TSFEL features for window-7155
# Extracted TSFEL features for window-7156
# Extracted TSFEL features for window-7157
# Extracted TSFEL features for window-7158
# Extracted TSFEL features for window-7159
# Extracted TSFEL features for window-7160
# Extracted TSFEL features for window-7161
# Extracted TSFEL features for window-7162
# Extracted TSFEL features for window-7163
# Extracted TSFEL features for window-7164
# Extracted TSFEL features for window-7165
# Extracted TSFEL features for window-7166
# Extracted TSFEL features for window-7167
# Extracted TSFEL features for window-7168
# Extracted TSFEL features for window-7169
# Extracted TSFEL features for window-7170
# Extracted TSFEL features for window-7171
# Extracted TSFEL features for window-7172
# Extracted TSFEL features for window-7173
# Extracted TSFEL features for window-7174
# Extracted TSFEL features for window-7175
# Extracted TSFEL features for window-7176
# Extracted TSFEL features for window-7177
# Extracted TSFEL features for window-7178
# Extracted TSFEL features for window-7179
# Extracted TSFEL features for window-7180
# Extracted TSFEL features for window-7181
# Extracted TSFEL features for window-7182
# Extracted TSFEL features for window-7183
# Extracted TSFEL features for window-7184
# Extracted TSFEL features for window-7185
# Extracted TSFEL features for window-7186
# Extracted TSFEL features for window-7187
# Extracted TSFEL features for window-7188
# Extracted TSFEL features for window-7189
# Extracted TSFEL features for window-7190
# Extracted TSFEL features for window-7191
# Extracted TSFEL features for window-7192
# Extracted TSFEL features for window-7193
# Extracted TSFEL features for window-7194
# Extracted TSFEL features for window-7195
# Extracted TSFEL features for window-7196
# Extracted TSFEL features for window-7197
# Extracted TSFEL features for window-7198
# Extracted TSFEL features for window-7199
# Extracted TSFEL features for window-7200
# Extracted TSFEL features for window-7201
# Extracted TSFEL features for window-7202
# Extracted TSFEL features for window-7203
# Extracted TSFEL features for window-7204
# Extracted TSFEL features for window-7205
# Extracted TSFEL features for window-7206
# Extracted TSFEL features for window-7207
# Extracted TSFEL features for window-7208
# Extracted TSFEL features for window-7209
# Extracted TSFEL features for window-7210
# Extracted TSFEL features for window-7211
# Extracted TSFEL features for window-7212
# Extracted TSFEL features for window-7213
# Extracted TSFEL features for window-7214
# Extracted TSFEL features for window-7215
# Extracted TSFEL features for window-7216
# Extracted TSFEL features for window-7217
# Extracted TSFEL features for window-7218
# Extracted TSFEL features for window-7219
# Extracted TSFEL features for window-7220
# Extracted TSFEL features for window-7221
# Extracted TSFEL features for window-7222
# Extracted TSFEL features for window-7223
# Extracted TSFEL features for window-7224
# Extracted TSFEL features for window-7225
# Extracted TSFEL features for window-7226
# Extracted TSFEL features for window-7227
# Extracted TSFEL features for window-7228
# Extracted TSFEL features for window-7229
# Extracted TSFEL features for window-7230
# Extracted TSFEL features for window-7231
# Extracted TSFEL features for window-7232
# Extracted TSFEL features for window-7233
# Extracted TSFEL features for window-7234
# Extracted TSFEL features for window-7235
# Extracted TSFEL features for window-7236
# Extracted TSFEL features for window-7237
# Extracted TSFEL features for window-7238
# Extracted TSFEL features for window-7239
# Extracted TSFEL features for window-7240
# Extracted TSFEL features for window-7241
# Extracted TSFEL features for window-7242
# Extracted TSFEL features for window-7243
# Extracted TSFEL features for window-7244
# Extracted TSFEL features for window-7245
# Extracted TSFEL features for window-7246
# Extracted TSFEL features for window-7247
# Extracted TSFEL features for window-7248
# Extracted TSFEL features for window-7249
# Extracted TSFEL features for window-7250
# Extracted TSFEL features for window-7251
# Extracted TSFEL features for window-7252
# Extracted TSFEL features for window-7253
# Extracted TSFEL features for window-7254
# Extracted TSFEL features for window-7255
# Extracted TSFEL features for window-7256
# Extracted TSFEL features for window-7257
# Extracted TSFEL features for window-7258
# Extracted TSFEL features for window-7259
# Extracted TSFEL features for window-7260
# Extracted TSFEL features for window-7261
# Extracted TSFEL features for window-7262
# Extracted TSFEL features for window-7263
# Extracted TSFEL features for window-7264
# Extracted TSFEL features for window-7265
# Extracted TSFEL features for window-7266
# Extracted TSFEL features for window-7267
# Extracted TSFEL features for window-7268
# Extracted TSFEL features for window-7269
# Extracted TSFEL features for window-7270
# Extracted TSFEL features for window-7271
# Extracted TSFEL features for window-7272
# Extracted TSFEL features for window-7273
# Extracted TSFEL features for window-7274
# Extracted TSFEL features for window-7275
# Extracted TSFEL features for window-7276
# Extracted TSFEL features for window-7277
# Extracted TSFEL features for window-7278
# Extracted TSFEL features for window-7279
# Extracted TSFEL features for window-7280
# Extracted TSFEL features for window-7281
# Extracted TSFEL features for window-7282
# Extracted TSFEL features for window-7283
# Extracted TSFEL features for window-7284
# Extracted TSFEL features for window-7285
# Extracted TSFEL features for window-7286
# Extracted TSFEL features for window-7287
# Extracted TSFEL features for window-7288
# Extracted TSFEL features for window-7289
# Extracted TSFEL features for window-7290
# Extracted TSFEL features for window-7291
# Extracted TSFEL features for window-7292
# Extracted TSFEL features for window-7293
# Extracted TSFEL features for window-7294
# Extracted TSFEL features for window-7295
# Extracted TSFEL features for window-7296
# Extracted TSFEL features for window-7297
# Extracted TSFEL features for window-7298
# Extracted TSFEL features for window-7299
# Extracted TSFEL features for window-7300
# Extracted TSFEL features for window-7301
# Extracted TSFEL features for window-7302
# Extracted TSFEL features for window-7303
# Extracted TSFEL features for window-7304
# Extracted TSFEL features for window-7305
# Extracted TSFEL features for window-7306
# Extracted TSFEL features for window-7307
# Extracted TSFEL features for window-7308
# Extracted TSFEL features for window-7309
# Extracted TSFEL features for window-7310
# Extracted TSFEL features for window-7311
# Extracted TSFEL features for window-7312
# Extracted TSFEL features for window-7313
# Extracted TSFEL features for window-7314
# Extracted TSFEL features for window-7315
# Extracted TSFEL features for window-7316
# Extracted TSFEL features for window-7317
# Extracted TSFEL features for window-7318
# Extracted TSFEL features for window-7319
# Extracted TSFEL features for window-7320
# Extracted TSFEL features for window-7321
# Extracted TSFEL features for window-7322
# Extracted TSFEL features for window-7323
# Extracted TSFEL features for window-7324
# Extracted TSFEL features for window-7325
# Extracted TSFEL features for window-7326
# Extracted TSFEL features for window-7327
# Extracted TSFEL features for window-7328
# Extracted TSFEL features for window-7329
# Extracted TSFEL features for window-7330
# Extracted TSFEL features for window-7331
# Extracted TSFEL features for window-7332
# Extracted TSFEL features for window-7333
# Extracted TSFEL features for window-7334
# Extracted TSFEL features for window-7335
# Extracted TSFEL features for window-7336
# Extracted TSFEL features for window-7337
# Extracted TSFEL features for window-7338
# Extracted TSFEL features for window-7339
# Extracted TSFEL features for window-7340
# Extracted TSFEL features for window-7341
# Extracted TSFEL features for window-7342
# Extracted TSFEL features for window-7343
# Extracted TSFEL features for window-7344
# Extracted TSFEL features for window-7345
# Extracted TSFEL features for window-7346
# Extracted TSFEL features for window-7347
# Extracted TSFEL features for window-7348
# Extracted TSFEL features for window-7349
# Extracted TSFEL features for window-7350
# Extracted TSFEL features for window-7351
# Extracted TSFEL features for window-7352

# %%
X_test_tsfel=get_tsfel_features(X_test_raw,'statistical')
# Out:
# Extracted TSFEL features for window-1
# Extracted TSFEL features for window-2
# Extracted TSFEL features for window-3
# Extracted TSFEL features for window-4
# Extracted TSFEL features for window-5
# Extracted TSFEL features for window-6
# Extracted TSFEL features for window-7
# Extracted TSFEL features for window-8
# Extracted TSFEL features for window-9
# Extracted TSFEL features for window-10
# Extracted TSFEL features for window-11
# Extracted TSFEL features for window-12
# Extracted TSFEL features for window-13
# Extracted TSFEL features for window-14
# Extracted TSFEL features for window-15
# Extracted TSFEL features for window-16
# Extracted TSFEL features for window-17
# Extracted TSFEL features for window-18
# Extracted TSFEL features for window-19
# Extracted TSFEL features for window-20
# Extracted TSFEL features for window-21
# Extracted TSFEL features for window-22
# Extracted TSFEL features for window-23
# Extracted TSFEL features for window-24
# Extracted TSFEL features for window-25
# Extracted TSFEL features for window-26
# Extracted TSFEL features for window-27
# Extracted TSFEL features for window-28
# Extracted TSFEL features for window-29
# Extracted TSFEL features for window-30
# Extracted TSFEL features for window-31
# Extracted TSFEL features for window-32
# Extracted TSFEL features for window-33
# Extracted TSFEL features for window-34
# Extracted TSFEL features for window-35
# Extracted TSFEL features for window-36
# Extracted TSFEL features for window-37
# Extracted TSFEL features for window-38
# Extracted TSFEL features for window-39
# Extracted TSFEL features for window-40
# Extracted TSFEL features for window-41
# Extracted TSFEL features for window-42
# Extracted TSFEL features for window-43
# Extracted TSFEL features for window-44
# Extracted TSFEL features for window-45
# Extracted TSFEL features for window-46
# Extracted TSFEL features for window-47
# Extracted TSFEL features for window-48
# Extracted TSFEL features for window-49
# Extracted TSFEL features for window-50
# Extracted TSFEL features for window-51
# Extracted TSFEL features for window-52
# Extracted TSFEL features for window-53
# Extracted TSFEL features for window-54
# Extracted TSFEL features for window-55
# Extracted TSFEL features for window-56
# Extracted TSFEL features for window-57
# Extracted TSFEL features for window-58
# Extracted TSFEL features for window-59
# Extracted TSFEL features for window-60
# Extracted TSFEL features for window-61
# Extracted TSFEL features for window-62
# Extracted TSFEL features for window-63
# Extracted TSFEL features for window-64
# Extracted TSFEL features for window-65
# Extracted TSFEL features for window-66
# Extracted TSFEL features for window-67
# Extracted TSFEL features for window-68
# Extracted TSFEL features for window-69
# Extracted TSFEL features for window-70
# Extracted TSFEL features for window-71
# Extracted TSFEL features for window-72
# Extracted TSFEL features for window-73
# Extracted TSFEL features for window-74
# Extracted TSFEL features for window-75
# Extracted TSFEL features for window-76
# Extracted TSFEL features for window-77
# Extracted TSFEL features for window-78
# Extracted TSFEL features for window-79
# Extracted TSFEL features for window-80
# Extracted TSFEL features for window-81
# Extracted TSFEL features for window-82
# Extracted TSFEL features for window-83
# Extracted TSFEL features for window-84
# Extracted TSFEL features for window-85
# Extracted TSFEL features for window-86
# Extracted TSFEL features for window-87
# Extracted TSFEL features for window-88
# Extracted TSFEL features for window-89
# Extracted TSFEL features for window-90
# Extracted TSFEL features for window-91
# Extracted TSFEL features for window-92
# Extracted TSFEL features for window-93
# Extracted TSFEL features for window-94
# Extracted TSFEL features for window-95
# Extracted TSFEL features for window-96
# Extracted TSFEL features for window-97
# Extracted TSFEL features for window-98
# Extracted TSFEL features for window-99
# Extracted TSFEL features for window-100
# Extracted TSFEL features for window-101
# Extracted TSFEL features for window-102
# Extracted TSFEL features for window-103
# Extracted TSFEL features for window-104
# Extracted TSFEL features for window-105
# Extracted TSFEL features for window-106
# Extracted TSFEL features for window-107
# Extracted TSFEL features for window-108
# Extracted TSFEL features for window-109
# Extracted TSFEL features for window-110
# Extracted TSFEL features for window-111
# Extracted TSFEL features for window-112
# Extracted TSFEL features for window-113
# Extracted TSFEL features for window-114
# Extracted TSFEL features for window-115
# Extracted TSFEL features for window-116
# Extracted TSFEL features for window-117
# Extracted TSFEL features for window-118
# Extracted TSFEL features for window-119
# Extracted TSFEL features for window-120
# Extracted TSFEL features for window-121
# Extracted TSFEL features for window-122
# Extracted TSFEL features for window-123
# Extracted TSFEL features for window-124
# Extracted TSFEL features for window-125
# Extracted TSFEL features for window-126
# Extracted TSFEL features for window-127
# Extracted TSFEL features for window-128
# Extracted TSFEL features for window-129
# Extracted TSFEL features for window-130
# Extracted TSFEL features for window-131
# Extracted TSFEL features for window-132
# Extracted TSFEL features for window-133
# Extracted TSFEL features for window-134
# Extracted TSFEL features for window-135
# Extracted TSFEL features for window-136
# Extracted TSFEL features for window-137
# Extracted TSFEL features for window-138
# Extracted TSFEL features for window-139
# Extracted TSFEL features for window-140
# Extracted TSFEL features for window-141
# Extracted TSFEL features for window-142
# Extracted TSFEL features for window-143
# Extracted TSFEL features for window-144
# Extracted TSFEL features for window-145
# Extracted TSFEL features for window-146
# Extracted TSFEL features for window-147
# Extracted TSFEL features for window-148
# Extracted TSFEL features for window-149
# Extracted TSFEL features for window-150
# Extracted TSFEL features for window-151
# Extracted TSFEL features for window-152
# Extracted TSFEL features for window-153
# Extracted TSFEL features for window-154
# Extracted TSFEL features for window-155
# Extracted TSFEL features for window-156
# Extracted TSFEL features for window-157
# Extracted TSFEL features for window-158
# Extracted TSFEL features for window-159
# Extracted TSFEL features for window-160
# Extracted TSFEL features for window-161
# Extracted TSFEL features for window-162
# Extracted TSFEL features for window-163
# Extracted TSFEL features for window-164
# Extracted TSFEL features for window-165
# Extracted TSFEL features for window-166
# Extracted TSFEL features for window-167
# Extracted TSFEL features for window-168
# Extracted TSFEL features for window-169
# Extracted TSFEL features for window-170
# Extracted TSFEL features for window-171
# Extracted TSFEL features for window-172
# Extracted TSFEL features for window-173
# Extracted TSFEL features for window-174
# Extracted TSFEL features for window-175
# Extracted TSFEL features for window-176
# Extracted TSFEL features for window-177
# Extracted TSFEL features for window-178
# Extracted TSFEL features for window-179
# Extracted TSFEL features for window-180
# Extracted TSFEL features for window-181
# Extracted TSFEL features for window-182
# Extracted TSFEL features for window-183
# Extracted TSFEL features for window-184
# Extracted TSFEL features for window-185
# Extracted TSFEL features for window-186
# Extracted TSFEL features for window-187
# Extracted TSFEL features for window-188
# Extracted TSFEL features for window-189
# Extracted TSFEL features for window-190
# Extracted TSFEL features for window-191
# Extracted TSFEL features for window-192
# Extracted TSFEL features for window-193
# Extracted TSFEL features for window-194
# Extracted TSFEL features for window-195
# Extracted TSFEL features for window-196
# Extracted TSFEL features for window-197
# Extracted TSFEL features for window-198
# Extracted TSFEL features for window-199
# Extracted TSFEL features for window-200
# Extracted TSFEL features for window-201
# Extracted TSFEL features for window-202
# Extracted TSFEL features for window-203
# Extracted TSFEL features for window-204
# Extracted TSFEL features for window-205
# Extracted TSFEL features for window-206
# Extracted TSFEL features for window-207
# Extracted TSFEL features for window-208
# Extracted TSFEL features for window-209
# Extracted TSFEL features for window-210
# Extracted TSFEL features for window-211
# Extracted TSFEL features for window-212
# Extracted TSFEL features for window-213
# Extracted TSFEL features for window-214
# Extracted TSFEL features for window-215
# Extracted TSFEL features for window-216
# Extracted TSFEL features for window-217
# Extracted TSFEL features for window-218
# Extracted TSFEL features for window-219
# Extracted TSFEL features for window-220
# Extracted TSFEL features for window-221
# Extracted TSFEL features for window-222
# Extracted TSFEL features for window-223
# Extracted TSFEL features for window-224
# Extracted TSFEL features for window-225
# Extracted TSFEL features for window-226
# Extracted TSFEL features for window-227
# Extracted TSFEL features for window-228
# Extracted TSFEL features for window-229
# Extracted TSFEL features for window-230
# Extracted TSFEL features for window-231
# Extracted TSFEL features for window-232
# Extracted TSFEL features for window-233
# Extracted TSFEL features for window-234
# Extracted TSFEL features for window-235
# Extracted TSFEL features for window-236
# Extracted TSFEL features for window-237
# Extracted TSFEL features for window-238
# Extracted TSFEL features for window-239
# Extracted TSFEL features for window-240
# Extracted TSFEL features for window-241
# Extracted TSFEL features for window-242
# Extracted TSFEL features for window-243
# Extracted TSFEL features for window-244
# Extracted TSFEL features for window-245
# Extracted TSFEL features for window-246
# Extracted TSFEL features for window-247
# Extracted TSFEL features for window-248
# Extracted TSFEL features for window-249
# Extracted TSFEL features for window-250
# Extracted TSFEL features for window-251
# Extracted TSFEL features for window-252
# Extracted TSFEL features for window-253
# Extracted TSFEL features for window-254
# Extracted TSFEL features for window-255
# Extracted TSFEL features for window-256
# Extracted TSFEL features for window-257
# Extracted TSFEL features for window-258
# Extracted TSFEL features for window-259
# Extracted TSFEL features for window-260
# Extracted TSFEL features for window-261
# Extracted TSFEL features for window-262
# Extracted TSFEL features for window-263
# Extracted TSFEL features for window-264
# Extracted TSFEL features for window-265
# Extracted TSFEL features for window-266
# Extracted TSFEL features for window-267
# Extracted TSFEL features for window-268
# Extracted TSFEL features for window-269
# Extracted TSFEL features for window-270
# Extracted TSFEL features for window-271
# Extracted TSFEL features for window-272
# Extracted TSFEL features for window-273
# Extracted TSFEL features for window-274
# Extracted TSFEL features for window-275
# Extracted TSFEL features for window-276
# Extracted TSFEL features for window-277
# Extracted TSFEL features for window-278
# Extracted TSFEL features for window-279
# Extracted TSFEL features for window-280
# Extracted TSFEL features for window-281
# Extracted TSFEL features for window-282
# Extracted TSFEL features for window-283
# Extracted TSFEL features for window-284
# Extracted TSFEL features for window-285
# Extracted TSFEL features for window-286
# Extracted TSFEL features for window-287
# Extracted TSFEL features for window-288
# Extracted TSFEL features for window-289
# Extracted TSFEL features for window-290
# Extracted TSFEL features for window-291
# Extracted TSFEL features for window-292
# Extracted TSFEL features for window-293
# Extracted TSFEL features for window-294
# Extracted TSFEL features for window-295
# Extracted TSFEL features for window-296
# Extracted TSFEL features for window-297
# Extracted TSFEL features for window-298
# Extracted TSFEL features for window-299
# Extracted TSFEL features for window-300
# Extracted TSFEL features for window-301
# Extracted TSFEL features for window-302
# Extracted TSFEL features for window-303
# Extracted TSFEL features for window-304
# Extracted TSFEL features for window-305
# Extracted TSFEL features for window-306
# Extracted TSFEL features for window-307
# Extracted TSFEL features for window-308
# Extracted TSFEL features for window-309
# Extracted TSFEL features for window-310
# Extracted TSFEL features for window-311
# Extracted TSFEL features for window-312
# Extracted TSFEL features for window-313
# Extracted TSFEL features for window-314
# Extracted TSFEL features for window-315
# Extracted TSFEL features for window-316
# Extracted TSFEL features for window-317
# Extracted TSFEL features for window-318
# Extracted TSFEL features for window-319
# Extracted TSFEL features for window-320
# Extracted TSFEL features for window-321
# Extracted TSFEL features for window-322
# Extracted TSFEL features for window-323
# Extracted TSFEL features for window-324
# Extracted TSFEL features for window-325
# Extracted TSFEL features for window-326
# Extracted TSFEL features for window-327
# Extracted TSFEL features for window-328
# Extracted TSFEL features for window-329
# Extracted TSFEL features for window-330
# Extracted TSFEL features for window-331
# Extracted TSFEL features for window-332
# Extracted TSFEL features for window-333
# Extracted TSFEL features for window-334
# Extracted TSFEL features for window-335
# Extracted TSFEL features for window-336
# Extracted TSFEL features for window-337
# Extracted TSFEL features for window-338
# Extracted TSFEL features for window-339
# Extracted TSFEL features for window-340
# Extracted TSFEL features for window-341
# Extracted TSFEL features for window-342
# Extracted TSFEL features for window-343
# Extracted TSFEL features for window-344
# Extracted TSFEL features for window-345
# Extracted TSFEL features for window-346
# Extracted TSFEL features for window-347
# Extracted TSFEL features for window-348
# Extracted TSFEL features for window-349
# Extracted TSFEL features for window-350
# Extracted TSFEL features for window-351
# Extracted TSFEL features for window-352
# Extracted TSFEL features for window-353
# Extracted TSFEL features for window-354
# Extracted TSFEL features for window-355
# Extracted TSFEL features for window-356
# Extracted TSFEL features for window-357
# Extracted TSFEL features for window-358
# Extracted TSFEL features for window-359
# Extracted TSFEL features for window-360
# Extracted TSFEL features for window-361
# Extracted TSFEL features for window-362
# Extracted TSFEL features for window-363
# Extracted TSFEL features for window-364
# Extracted TSFEL features for window-365
# Extracted TSFEL features for window-366
# Extracted TSFEL features for window-367
# Extracted TSFEL features for window-368
# Extracted TSFEL features for window-369
# Extracted TSFEL features for window-370
# Extracted TSFEL features for window-371
# Extracted TSFEL features for window-372
# Extracted TSFEL features for window-373
# Extracted TSFEL features for window-374
# Extracted TSFEL features for window-375
# Extracted TSFEL features for window-376
# Extracted TSFEL features for window-377
# Extracted TSFEL features for window-378
# Extracted TSFEL features for window-379
# Extracted TSFEL features for window-380
# Extracted TSFEL features for window-381
# Extracted TSFEL features for window-382
# Extracted TSFEL features for window-383
# Extracted TSFEL features for window-384
# Extracted TSFEL features for window-385
# Extracted TSFEL features for window-386
# Extracted TSFEL features for window-387
# Extracted TSFEL features for window-388
# Extracted TSFEL features for window-389
# Extracted TSFEL features for window-390
# Extracted TSFEL features for window-391
# Extracted TSFEL features for window-392
# Extracted TSFEL features for window-393
# Extracted TSFEL features for window-394
# Extracted TSFEL features for window-395
# Extracted TSFEL features for window-396
# Extracted TSFEL features for window-397
# Extracted TSFEL features for window-398
# Extracted TSFEL features for window-399
# Extracted TSFEL features for window-400
# Extracted TSFEL features for window-401
# Extracted TSFEL features for window-402
# Extracted TSFEL features for window-403
# Extracted TSFEL features for window-404
# Extracted TSFEL features for window-405
# Extracted TSFEL features for window-406
# Extracted TSFEL features for window-407
# Extracted TSFEL features for window-408
# Extracted TSFEL features for window-409
# Extracted TSFEL features for window-410
# Extracted TSFEL features for window-411
# Extracted TSFEL features for window-412
# Extracted TSFEL features for window-413
# Extracted TSFEL features for window-414
# Extracted TSFEL features for window-415
# Extracted TSFEL features for window-416
# Extracted TSFEL features for window-417
# Extracted TSFEL features for window-418
# Extracted TSFEL features for window-419
# Extracted TSFEL features for window-420
# Extracted TSFEL features for window-421
# Extracted TSFEL features for window-422
# Extracted TSFEL features for window-423
# Extracted TSFEL features for window-424
# Extracted TSFEL features for window-425
# Extracted TSFEL features for window-426
# Extracted TSFEL features for window-427
# Extracted TSFEL features for window-428
# Extracted TSFEL features for window-429
# Extracted TSFEL features for window-430
# Extracted TSFEL features for window-431
# Extracted TSFEL features for window-432
# Extracted TSFEL features for window-433
# Extracted TSFEL features for window-434
# Extracted TSFEL features for window-435
# Extracted TSFEL features for window-436
# Extracted TSFEL features for window-437
# Extracted TSFEL features for window-438
# Extracted TSFEL features for window-439
# Extracted TSFEL features for window-440
# Extracted TSFEL features for window-441
# Extracted TSFEL features for window-442
# Extracted TSFEL features for window-443
# Extracted TSFEL features for window-444
# Extracted TSFEL features for window-445
# Extracted TSFEL features for window-446
# Extracted TSFEL features for window-447
# Extracted TSFEL features for window-448
# Extracted TSFEL features for window-449
# Extracted TSFEL features for window-450
# Extracted TSFEL features for window-451
# Extracted TSFEL features for window-452
# Extracted TSFEL features for window-453
# Extracted TSFEL features for window-454
# Extracted TSFEL features for window-455
# Extracted TSFEL features for window-456
# Extracted TSFEL features for window-457
# Extracted TSFEL features for window-458
# Extracted TSFEL features for window-459
# Extracted TSFEL features for window-460
# Extracted TSFEL features for window-461
# Extracted TSFEL features for window-462
# Extracted TSFEL features for window-463
# Extracted TSFEL features for window-464
# Extracted TSFEL features for window-465
# Extracted TSFEL features for window-466
# Extracted TSFEL features for window-467
# Extracted TSFEL features for window-468
# Extracted TSFEL features for window-469
# Extracted TSFEL features for window-470
# Extracted TSFEL features for window-471
# Extracted TSFEL features for window-472
# Extracted TSFEL features for window-473
# Extracted TSFEL features for window-474
# Extracted TSFEL features for window-475
# Extracted TSFEL features for window-476
# Extracted TSFEL features for window-477
# Extracted TSFEL features for window-478
# Extracted TSFEL features for window-479
# Extracted TSFEL features for window-480
# Extracted TSFEL features for window-481
# Extracted TSFEL features for window-482
# Extracted TSFEL features for window-483
# Extracted TSFEL features for window-484
# Extracted TSFEL features for window-485
# Extracted TSFEL features for window-486
# Extracted TSFEL features for window-487
# Extracted TSFEL features for window-488
# Extracted TSFEL features for window-489
# Extracted TSFEL features for window-490
# Extracted TSFEL features for window-491
# Extracted TSFEL features for window-492
# Extracted TSFEL features for window-493
# Extracted TSFEL features for window-494
# Extracted TSFEL features for window-495
# Extracted TSFEL features for window-496
# Extracted TSFEL features for window-497
# Extracted TSFEL features for window-498
# Extracted TSFEL features for window-499
# Extracted TSFEL features for window-500
# Extracted TSFEL features for window-501
# Extracted TSFEL features for window-502
# Extracted TSFEL features for window-503
# Extracted TSFEL features for window-504
# Extracted TSFEL features for window-505
# Extracted TSFEL features for window-506
# Extracted TSFEL features for window-507
# Extracted TSFEL features for window-508
# Extracted TSFEL features for window-509
# Extracted TSFEL features for window-510
# Extracted TSFEL features for window-511
# Extracted TSFEL features for window-512
# Extracted TSFEL features for window-513
# Extracted TSFEL features for window-514
# Extracted TSFEL features for window-515
# Extracted TSFEL features for window-516
# Extracted TSFEL features for window-517
# Extracted TSFEL features for window-518
# Extracted TSFEL features for window-519
# Extracted TSFEL features for window-520
# Extracted TSFEL features for window-521
# Extracted TSFEL features for window-522
# Extracted TSFEL features for window-523
# Extracted TSFEL features for window-524
# Extracted TSFEL features for window-525
# Extracted TSFEL features for window-526
# Extracted TSFEL features for window-527
# Extracted TSFEL features for window-528
# Extracted TSFEL features for window-529
# Extracted TSFEL features for window-530
# Extracted TSFEL features for window-531
# Extracted TSFEL features for window-532
# Extracted TSFEL features for window-533
# Extracted TSFEL features for window-534
# Extracted TSFEL features for window-535
# Extracted TSFEL features for window-536
# Extracted TSFEL features for window-537
# Extracted TSFEL features for window-538
# Extracted TSFEL features for window-539
# Extracted TSFEL features for window-540
# Extracted TSFEL features for window-541
# Extracted TSFEL features for window-542
# Extracted TSFEL features for window-543
# Extracted TSFEL features for window-544
# Extracted TSFEL features for window-545
# Extracted TSFEL features for window-546
# Extracted TSFEL features for window-547
# Extracted TSFEL features for window-548
# Extracted TSFEL features for window-549
# Extracted TSFEL features for window-550
# Extracted TSFEL features for window-551
# Extracted TSFEL features for window-552
# Extracted TSFEL features for window-553
# Extracted TSFEL features for window-554
# Extracted TSFEL features for window-555
# Extracted TSFEL features for window-556
# Extracted TSFEL features for window-557
# Extracted TSFEL features for window-558
# Extracted TSFEL features for window-559
# Extracted TSFEL features for window-560
# Extracted TSFEL features for window-561
# Extracted TSFEL features for window-562
# Extracted TSFEL features for window-563
# Extracted TSFEL features for window-564
# Extracted TSFEL features for window-565
# Extracted TSFEL features for window-566
# Extracted TSFEL features for window-567
# Extracted TSFEL features for window-568
# Extracted TSFEL features for window-569
# Extracted TSFEL features for window-570
# Extracted TSFEL features for window-571
# Extracted TSFEL features for window-572
# Extracted TSFEL features for window-573
# Extracted TSFEL features for window-574
# Extracted TSFEL features for window-575
# Extracted TSFEL features for window-576
# Extracted TSFEL features for window-577
# Extracted TSFEL features for window-578
# Extracted TSFEL features for window-579
# Extracted TSFEL features for window-580
# Extracted TSFEL features for window-581
# Extracted TSFEL features for window-582
# Extracted TSFEL features for window-583
# Extracted TSFEL features for window-584
# Extracted TSFEL features for window-585
# Extracted TSFEL features for window-586
# Extracted TSFEL features for window-587
# Extracted TSFEL features for window-588
# Extracted TSFEL features for window-589
# Extracted TSFEL features for window-590
# Extracted TSFEL features for window-591
# Extracted TSFEL features for window-592
# Extracted TSFEL features for window-593
# Extracted TSFEL features for window-594
# Extracted TSFEL features for window-595
# Extracted TSFEL features for window-596
# Extracted TSFEL features for window-597
# Extracted TSFEL features for window-598
# Extracted TSFEL features for window-599
# Extracted TSFEL features for window-600
# Extracted TSFEL features for window-601
# Extracted TSFEL features for window-602
# Extracted TSFEL features for window-603
# Extracted TSFEL features for window-604
# Extracted TSFEL features for window-605
# Extracted TSFEL features for window-606
# Extracted TSFEL features for window-607
# Extracted TSFEL features for window-608
# Extracted TSFEL features for window-609
# Extracted TSFEL features for window-610
# Extracted TSFEL features for window-611
# Extracted TSFEL features for window-612
# Extracted TSFEL features for window-613
# Extracted TSFEL features for window-614
# Extracted TSFEL features for window-615
# Extracted TSFEL features for window-616
# Extracted TSFEL features for window-617
# Extracted TSFEL features for window-618
# Extracted TSFEL features for window-619
# Extracted TSFEL features for window-620
# Extracted TSFEL features for window-621
# Extracted TSFEL features for window-622
# Extracted TSFEL features for window-623
# Extracted TSFEL features for window-624
# Extracted TSFEL features for window-625
# Extracted TSFEL features for window-626
# Extracted TSFEL features for window-627
# Extracted TSFEL features for window-628
# Extracted TSFEL features for window-629
# Extracted TSFEL features for window-630
# Extracted TSFEL features for window-631
# Extracted TSFEL features for window-632
# Extracted TSFEL features for window-633
# Extracted TSFEL features for window-634
# Extracted TSFEL features for window-635
# Extracted TSFEL features for window-636
# Extracted TSFEL features for window-637
# Extracted TSFEL features for window-638
# Extracted TSFEL features for window-639
# Extracted TSFEL features for window-640
# Extracted TSFEL features for window-641
# Extracted TSFEL features for window-642
# Extracted TSFEL features for window-643
# Extracted TSFEL features for window-644
# Extracted TSFEL features for window-645
# Extracted TSFEL features for window-646
# Extracted TSFEL features for window-647
# Extracted TSFEL features for window-648
# Extracted TSFEL features for window-649
# Extracted TSFEL features for window-650
# Extracted TSFEL features for window-651
# Extracted TSFEL features for window-652
# Extracted TSFEL features for window-653
# Extracted TSFEL features for window-654
# Extracted TSFEL features for window-655
# Extracted TSFEL features for window-656
# Extracted TSFEL features for window-657
# Extracted TSFEL features for window-658
# Extracted TSFEL features for window-659
# Extracted TSFEL features for window-660
# Extracted TSFEL features for window-661
# Extracted TSFEL features for window-662
# Extracted TSFEL features for window-663
# Extracted TSFEL features for window-664
# Extracted TSFEL features for window-665
# Extracted TSFEL features for window-666
# Extracted TSFEL features for window-667
# Extracted TSFEL features for window-668
# Extracted TSFEL features for window-669
# Extracted TSFEL features for window-670
# Extracted TSFEL features for window-671
# Extracted TSFEL features for window-672
# Extracted TSFEL features for window-673
# Extracted TSFEL features for window-674
# Extracted TSFEL features for window-675
# Extracted TSFEL features for window-676
# Extracted TSFEL features for window-677
# Extracted TSFEL features for window-678
# Extracted TSFEL features for window-679
# Extracted TSFEL features for window-680
# Extracted TSFEL features for window-681
# Extracted TSFEL features for window-682
# Extracted TSFEL features for window-683
# Extracted TSFEL features for window-684
# Extracted TSFEL features for window-685
# Extracted TSFEL features for window-686
# Extracted TSFEL features for window-687
# Extracted TSFEL features for window-688
# Extracted TSFEL features for window-689
# Extracted TSFEL features for window-690
# Extracted TSFEL features for window-691
# Extracted TSFEL features for window-692
# Extracted TSFEL features for window-693
# Extracted TSFEL features for window-694
# Extracted TSFEL features for window-695
# Extracted TSFEL features for window-696
# Extracted TSFEL features for window-697
# Extracted TSFEL features for window-698
# Extracted TSFEL features for window-699
# Extracted TSFEL features for window-700
# Extracted TSFEL features for window-701
# Extracted TSFEL features for window-702
# Extracted TSFEL features for window-703
# Extracted TSFEL features for window-704
# Extracted TSFEL features for window-705
# Extracted TSFEL features for window-706
# Extracted TSFEL features for window-707
# Extracted TSFEL features for window-708
# Extracted TSFEL features for window-709
# Extracted TSFEL features for window-710
# Extracted TSFEL features for window-711
# Extracted TSFEL features for window-712
# Extracted TSFEL features for window-713
# Extracted TSFEL features for window-714
# Extracted TSFEL features for window-715
# Extracted TSFEL features for window-716
# Extracted TSFEL features for window-717
# Extracted TSFEL features for window-718
# Extracted TSFEL features for window-719
# Extracted TSFEL features for window-720
# Extracted TSFEL features for window-721
# Extracted TSFEL features for window-722
# Extracted TSFEL features for window-723
# Extracted TSFEL features for window-724
# Extracted TSFEL features for window-725
# Extracted TSFEL features for window-726
# Extracted TSFEL features for window-727
# Extracted TSFEL features for window-728
# Extracted TSFEL features for window-729
# Extracted TSFEL features for window-730
# Extracted TSFEL features for window-731
# Extracted TSFEL features for window-732
# Extracted TSFEL features for window-733
# Extracted TSFEL features for window-734
# Extracted TSFEL features for window-735
# Extracted TSFEL features for window-736
# Extracted TSFEL features for window-737
# Extracted TSFEL features for window-738
# Extracted TSFEL features for window-739
# Extracted TSFEL features for window-740
# Extracted TSFEL features for window-741
# Extracted TSFEL features for window-742
# Extracted TSFEL features for window-743
# Extracted TSFEL features for window-744
# Extracted TSFEL features for window-745
# Extracted TSFEL features for window-746
# Extracted TSFEL features for window-747
# Extracted TSFEL features for window-748
# Extracted TSFEL features for window-749
# Extracted TSFEL features for window-750
# Extracted TSFEL features for window-751
# Extracted TSFEL features for window-752
# Extracted TSFEL features for window-753
# Extracted TSFEL features for window-754
# Extracted TSFEL features for window-755
# Extracted TSFEL features for window-756
# Extracted TSFEL features for window-757
# Extracted TSFEL features for window-758
# Extracted TSFEL features for window-759
# Extracted TSFEL features for window-760
# Extracted TSFEL features for window-761
# Extracted TSFEL features for window-762
# Extracted TSFEL features for window-763
# Extracted TSFEL features for window-764
# Extracted TSFEL features for window-765
# Extracted TSFEL features for window-766
# Extracted TSFEL features for window-767
# Extracted TSFEL features for window-768
# Extracted TSFEL features for window-769
# Extracted TSFEL features for window-770
# Extracted TSFEL features for window-771
# Extracted TSFEL features for window-772
# Extracted TSFEL features for window-773
# Extracted TSFEL features for window-774
# Extracted TSFEL features for window-775
# Extracted TSFEL features for window-776
# Extracted TSFEL features for window-777
# Extracted TSFEL features for window-778
# Extracted TSFEL features for window-779
# Extracted TSFEL features for window-780
# Extracted TSFEL features for window-781
# Extracted TSFEL features for window-782
# Extracted TSFEL features for window-783
# Extracted TSFEL features for window-784
# Extracted TSFEL features for window-785
# Extracted TSFEL features for window-786
# Extracted TSFEL features for window-787
# Extracted TSFEL features for window-788
# Extracted TSFEL features for window-789
# Extracted TSFEL features for window-790
# Extracted TSFEL features for window-791
# Extracted TSFEL features for window-792
# Extracted TSFEL features for window-793
# Extracted TSFEL features for window-794
# Extracted TSFEL features for window-795
# Extracted TSFEL features for window-796
# Extracted TSFEL features for window-797
# Extracted TSFEL features for window-798
# Extracted TSFEL features for window-799
# Extracted TSFEL features for window-800
# Extracted TSFEL features for window-801
# Extracted TSFEL features for window-802
# Extracted TSFEL features for window-803
# Extracted TSFEL features for window-804
# Extracted TSFEL features for window-805
# Extracted TSFEL features for window-806
# Extracted TSFEL features for window-807
# Extracted TSFEL features for window-808
# Extracted TSFEL features for window-809
# Extracted TSFEL features for window-810
# Extracted TSFEL features for window-811
# Extracted TSFEL features for window-812
# Extracted TSFEL features for window-813
# Extracted TSFEL features for window-814
# Extracted TSFEL features for window-815
# Extracted TSFEL features for window-816
# Extracted TSFEL features for window-817
# Extracted TSFEL features for window-818
# Extracted TSFEL features for window-819
# Extracted TSFEL features for window-820
# Extracted TSFEL features for window-821
# Extracted TSFEL features for window-822
# Extracted TSFEL features for window-823
# Extracted TSFEL features for window-824
# Extracted TSFEL features for window-825
# Extracted TSFEL features for window-826
# Extracted TSFEL features for window-827
# Extracted TSFEL features for window-828
# Extracted TSFEL features for window-829
# Extracted TSFEL features for window-830
# Extracted TSFEL features for window-831
# Extracted TSFEL features for window-832
# Extracted TSFEL features for window-833
# Extracted TSFEL features for window-834
# Extracted TSFEL features for window-835
# Extracted TSFEL features for window-836
# Extracted TSFEL features for window-837
# Extracted TSFEL features for window-838
# Extracted TSFEL features for window-839
# Extracted TSFEL features for window-840
# Extracted TSFEL features for window-841
# Extracted TSFEL features for window-842
# Extracted TSFEL features for window-843
# Extracted TSFEL features for window-844
# Extracted TSFEL features for window-845
# Extracted TSFEL features for window-846
# Extracted TSFEL features for window-847
# Extracted TSFEL features for window-848
# Extracted TSFEL features for window-849
# Extracted TSFEL features for window-850
# Extracted TSFEL features for window-851
# Extracted TSFEL features for window-852
# Extracted TSFEL features for window-853
# Extracted TSFEL features for window-854
# Extracted TSFEL features for window-855
# Extracted TSFEL features for window-856
# Extracted TSFEL features for window-857
# Extracted TSFEL features for window-858
# Extracted TSFEL features for window-859
# Extracted TSFEL features for window-860
# Extracted TSFEL features for window-861
# Extracted TSFEL features for window-862
# Extracted TSFEL features for window-863
# Extracted TSFEL features for window-864
# Extracted TSFEL features for window-865
# Extracted TSFEL features for window-866
# Extracted TSFEL features for window-867
# Extracted TSFEL features for window-868
# Extracted TSFEL features for window-869
# Extracted TSFEL features for window-870
# Extracted TSFEL features for window-871
# Extracted TSFEL features for window-872
# Extracted TSFEL features for window-873
# Extracted TSFEL features for window-874
# Extracted TSFEL features for window-875
# Extracted TSFEL features for window-876
# Extracted TSFEL features for window-877
# Extracted TSFEL features for window-878
# Extracted TSFEL features for window-879
# Extracted TSFEL features for window-880
# Extracted TSFEL features for window-881
# Extracted TSFEL features for window-882
# Extracted TSFEL features for window-883
# Extracted TSFEL features for window-884
# Extracted TSFEL features for window-885
# Extracted TSFEL features for window-886
# Extracted TSFEL features for window-887
# Extracted TSFEL features for window-888
# Extracted TSFEL features for window-889
# Extracted TSFEL features for window-890
# Extracted TSFEL features for window-891
# Extracted TSFEL features for window-892
# Extracted TSFEL features for window-893
# Extracted TSFEL features for window-894
# Extracted TSFEL features for window-895
# Extracted TSFEL features for window-896
# Extracted TSFEL features for window-897
# Extracted TSFEL features for window-898
# Extracted TSFEL features for window-899
# Extracted TSFEL features for window-900
# Extracted TSFEL features for window-901
# Extracted TSFEL features for window-902
# Extracted TSFEL features for window-903
# Extracted TSFEL features for window-904
# Extracted TSFEL features for window-905
# Extracted TSFEL features for window-906
# Extracted TSFEL features for window-907
# Extracted TSFEL features for window-908
# Extracted TSFEL features for window-909
# Extracted TSFEL features for window-910
# Extracted TSFEL features for window-911
# Extracted TSFEL features for window-912
# Extracted TSFEL features for window-913
# Extracted TSFEL features for window-914
# Extracted TSFEL features for window-915
# Extracted TSFEL features for window-916
# Extracted TSFEL features for window-917
# Extracted TSFEL features for window-918
# Extracted TSFEL features for window-919
# Extracted TSFEL features for window-920
# Extracted TSFEL features for window-921
# Extracted TSFEL features for window-922
# Extracted TSFEL features for window-923
# Extracted TSFEL features for window-924
# Extracted TSFEL features for window-925
# Extracted TSFEL features for window-926
# Extracted TSFEL features for window-927
# Extracted TSFEL features for window-928
# Extracted TSFEL features for window-929
# Extracted TSFEL features for window-930
# Extracted TSFEL features for window-931
# Extracted TSFEL features for window-932
# Extracted TSFEL features for window-933
# Extracted TSFEL features for window-934
# Extracted TSFEL features for window-935
# Extracted TSFEL features for window-936
# Extracted TSFEL features for window-937
# Extracted TSFEL features for window-938
# Extracted TSFEL features for window-939
# Extracted TSFEL features for window-940
# Extracted TSFEL features for window-941
# Extracted TSFEL features for window-942
# Extracted TSFEL features for window-943
# Extracted TSFEL features for window-944
# Extracted TSFEL features for window-945
# Extracted TSFEL features for window-946
# Extracted TSFEL features for window-947
# Extracted TSFEL features for window-948
# Extracted TSFEL features for window-949
# Extracted TSFEL features for window-950
# Extracted TSFEL features for window-951
# Extracted TSFEL features for window-952
# Extracted TSFEL features for window-953
# Extracted TSFEL features for window-954
# Extracted TSFEL features for window-955
# Extracted TSFEL features for window-956
# Extracted TSFEL features for window-957
# Extracted TSFEL features for window-958
# Extracted TSFEL features for window-959
# Extracted TSFEL features for window-960
# Extracted TSFEL features for window-961
# Extracted TSFEL features for window-962
# Extracted TSFEL features for window-963
# Extracted TSFEL features for window-964
# Extracted TSFEL features for window-965
# Extracted TSFEL features for window-966
# Extracted TSFEL features for window-967
# Extracted TSFEL features for window-968
# Extracted TSFEL features for window-969
# Extracted TSFEL features for window-970
# Extracted TSFEL features for window-971
# Extracted TSFEL features for window-972
# Extracted TSFEL features for window-973
# Extracted TSFEL features for window-974
# Extracted TSFEL features for window-975
# Extracted TSFEL features for window-976
# Extracted TSFEL features for window-977
# Extracted TSFEL features for window-978
# Extracted TSFEL features for window-979
# Extracted TSFEL features for window-980
# Extracted TSFEL features for window-981
# Extracted TSFEL features for window-982
# Extracted TSFEL features for window-983
# Extracted TSFEL features for window-984
# Extracted TSFEL features for window-985
# Extracted TSFEL features for window-986
# Extracted TSFEL features for window-987
# Extracted TSFEL features for window-988
# Extracted TSFEL features for window-989
# Extracted TSFEL features for window-990
# Extracted TSFEL features for window-991
# Extracted TSFEL features for window-992
# Extracted TSFEL features for window-993
# Extracted TSFEL features for window-994
# Extracted TSFEL features for window-995
# Extracted TSFEL features for window-996
# Extracted TSFEL features for window-997
# Extracted TSFEL features for window-998
# Extracted TSFEL features for window-999
# Extracted TSFEL features for window-1000
# Extracted TSFEL features for window-1001
# Extracted TSFEL features for window-1002
# Extracted TSFEL features for window-1003
# Extracted TSFEL features for window-1004
# Extracted TSFEL features for window-1005
# Extracted TSFEL features for window-1006
# Extracted TSFEL features for window-1007
# Extracted TSFEL features for window-1008
# Extracted TSFEL features for window-1009
# Extracted TSFEL features for window-1010
# Extracted TSFEL features for window-1011
# Extracted TSFEL features for window-1012
# Extracted TSFEL features for window-1013
# Extracted TSFEL features for window-1014
# Extracted TSFEL features for window-1015
# Extracted TSFEL features for window-1016
# Extracted TSFEL features for window-1017
# Extracted TSFEL features for window-1018
# Extracted TSFEL features for window-1019
# Extracted TSFEL features for window-1020
# Extracted TSFEL features for window-1021
# Extracted TSFEL features for window-1022
# Extracted TSFEL features for window-1023
# Extracted TSFEL features for window-1024
# Extracted TSFEL features for window-1025
# Extracted TSFEL features for window-1026
# Extracted TSFEL features for window-1027
# Extracted TSFEL features for window-1028
# Extracted TSFEL features for window-1029
# Extracted TSFEL features for window-1030
# Extracted TSFEL features for window-1031
# Extracted TSFEL features for window-1032
# Extracted TSFEL features for window-1033
# Extracted TSFEL features for window-1034
# Extracted TSFEL features for window-1035
# Extracted TSFEL features for window-1036
# Extracted TSFEL features for window-1037
# Extracted TSFEL features for window-1038
# Extracted TSFEL features for window-1039
# Extracted TSFEL features for window-1040
# Extracted TSFEL features for window-1041
# Extracted TSFEL features for window-1042
# Extracted TSFEL features for window-1043
# Extracted TSFEL features for window-1044
# Extracted TSFEL features for window-1045
# Extracted TSFEL features for window-1046
# Extracted TSFEL features for window-1047
# Extracted TSFEL features for window-1048
# Extracted TSFEL features for window-1049
# Extracted TSFEL features for window-1050
# Extracted TSFEL features for window-1051
# Extracted TSFEL features for window-1052
# Extracted TSFEL features for window-1053
# Extracted TSFEL features for window-1054
# Extracted TSFEL features for window-1055
# Extracted TSFEL features for window-1056
# Extracted TSFEL features for window-1057
# Extracted TSFEL features for window-1058
# Extracted TSFEL features for window-1059
# Extracted TSFEL features for window-1060
# Extracted TSFEL features for window-1061
# Extracted TSFEL features for window-1062
# Extracted TSFEL features for window-1063
# Extracted TSFEL features for window-1064
# Extracted TSFEL features for window-1065
# Extracted TSFEL features for window-1066
# Extracted TSFEL features for window-1067
# Extracted TSFEL features for window-1068
# Extracted TSFEL features for window-1069
# Extracted TSFEL features for window-1070
# Extracted TSFEL features for window-1071
# Extracted TSFEL features for window-1072
# Extracted TSFEL features for window-1073
# Extracted TSFEL features for window-1074
# Extracted TSFEL features for window-1075
# Extracted TSFEL features for window-1076
# Extracted TSFEL features for window-1077
# Extracted TSFEL features for window-1078
# Extracted TSFEL features for window-1079
# Extracted TSFEL features for window-1080
# Extracted TSFEL features for window-1081
# Extracted TSFEL features for window-1082
# Extracted TSFEL features for window-1083
# Extracted TSFEL features for window-1084
# Extracted TSFEL features for window-1085
# Extracted TSFEL features for window-1086
# Extracted TSFEL features for window-1087
# Extracted TSFEL features for window-1088
# Extracted TSFEL features for window-1089
# Extracted TSFEL features for window-1090
# Extracted TSFEL features for window-1091
# Extracted TSFEL features for window-1092
# Extracted TSFEL features for window-1093
# Extracted TSFEL features for window-1094
# Extracted TSFEL features for window-1095
# Extracted TSFEL features for window-1096
# Extracted TSFEL features for window-1097
# Extracted TSFEL features for window-1098
# Extracted TSFEL features for window-1099
# Extracted TSFEL features for window-1100
# Extracted TSFEL features for window-1101
# Extracted TSFEL features for window-1102
# Extracted TSFEL features for window-1103
# Extracted TSFEL features for window-1104
# Extracted TSFEL features for window-1105
# Extracted TSFEL features for window-1106
# Extracted TSFEL features for window-1107
# Extracted TSFEL features for window-1108
# Extracted TSFEL features for window-1109
# Extracted TSFEL features for window-1110
# Extracted TSFEL features for window-1111
# Extracted TSFEL features for window-1112
# Extracted TSFEL features for window-1113
# Extracted TSFEL features for window-1114
# Extracted TSFEL features for window-1115
# Extracted TSFEL features for window-1116
# Extracted TSFEL features for window-1117
# Extracted TSFEL features for window-1118
# Extracted TSFEL features for window-1119
# Extracted TSFEL features for window-1120
# Extracted TSFEL features for window-1121
# Extracted TSFEL features for window-1122
# Extracted TSFEL features for window-1123
# Extracted TSFEL features for window-1124
# Extracted TSFEL features for window-1125
# Extracted TSFEL features for window-1126
# Extracted TSFEL features for window-1127
# Extracted TSFEL features for window-1128
# Extracted TSFEL features for window-1129
# Extracted TSFEL features for window-1130
# Extracted TSFEL features for window-1131
# Extracted TSFEL features for window-1132
# Extracted TSFEL features for window-1133
# Extracted TSFEL features for window-1134
# Extracted TSFEL features for window-1135
# Extracted TSFEL features for window-1136
# Extracted TSFEL features for window-1137
# Extracted TSFEL features for window-1138
# Extracted TSFEL features for window-1139
# Extracted TSFEL features for window-1140
# Extracted TSFEL features for window-1141
# Extracted TSFEL features for window-1142
# Extracted TSFEL features for window-1143
# Extracted TSFEL features for window-1144
# Extracted TSFEL features for window-1145
# Extracted TSFEL features for window-1146
# Extracted TSFEL features for window-1147
# Extracted TSFEL features for window-1148
# Extracted TSFEL features for window-1149
# Extracted TSFEL features for window-1150
# Extracted TSFEL features for window-1151
# Extracted TSFEL features for window-1152
# Extracted TSFEL features for window-1153
# Extracted TSFEL features for window-1154
# Extracted TSFEL features for window-1155
# Extracted TSFEL features for window-1156
# Extracted TSFEL features for window-1157
# Extracted TSFEL features for window-1158
# Extracted TSFEL features for window-1159
# Extracted TSFEL features for window-1160
# Extracted TSFEL features for window-1161
# Extracted TSFEL features for window-1162
# Extracted TSFEL features for window-1163
# Extracted TSFEL features for window-1164
# Extracted TSFEL features for window-1165
# Extracted TSFEL features for window-1166
# Extracted TSFEL features for window-1167
# Extracted TSFEL features for window-1168
# Extracted TSFEL features for window-1169
# Extracted TSFEL features for window-1170
# Extracted TSFEL features for window-1171
# Extracted TSFEL features for window-1172
# Extracted TSFEL features for window-1173
# Extracted TSFEL features for window-1174
# Extracted TSFEL features for window-1175
# Extracted TSFEL features for window-1176
# Extracted TSFEL features for window-1177
# Extracted TSFEL features for window-1178
# Extracted TSFEL features for window-1179
# Extracted TSFEL features for window-1180
# Extracted TSFEL features for window-1181
# Extracted TSFEL features for window-1182
# Extracted TSFEL features for window-1183
# Extracted TSFEL features for window-1184
# Extracted TSFEL features for window-1185
# Extracted TSFEL features for window-1186
# Extracted TSFEL features for window-1187
# Extracted TSFEL features for window-1188
# Extracted TSFEL features for window-1189
# Extracted TSFEL features for window-1190
# Extracted TSFEL features for window-1191
# Extracted TSFEL features for window-1192
# Extracted TSFEL features for window-1193
# Extracted TSFEL features for window-1194
# Extracted TSFEL features for window-1195
# Extracted TSFEL features for window-1196
# Extracted TSFEL features for window-1197
# ...
# Extracted TSFEL features for window-2558
# Extracted TSFEL features for window-2559
# Extracted TSFEL features for window-2560
# Extracted TSFEL features for window-2561
# Extracted TSFEL features for window-2562
# Extracted TSFEL features for window-2563
# Extracted TSFEL features for window-2564
# Extracted TSFEL features for window-2565
# Extracted TSFEL features for window-2566
# Extracted TSFEL features for window-2567
# Extracted TSFEL features for window-2568
# Extracted TSFEL features for window-2569
# Extracted TSFEL features for window-2570
# Extracted TSFEL features for window-2571
# Extracted TSFEL features for window-2572
# Extracted TSFEL features for window-2573
# Extracted TSFEL features for window-2574
# Extracted TSFEL features for window-2575
# Extracted TSFEL features for window-2576
# Extracted TSFEL features for window-2577
# Extracted TSFEL features for window-2578
# Extracted TSFEL features for window-2579
# Extracted TSFEL features for window-2580
# Extracted TSFEL features for window-2581
# Extracted TSFEL features for window-2582
# Extracted TSFEL features for window-2583
# Extracted TSFEL features for window-2584
# Extracted TSFEL features for window-2585
# Extracted TSFEL features for window-2586
# Extracted TSFEL features for window-2587
# Extracted TSFEL features for window-2588
# Extracted TSFEL features for window-2589
# Extracted TSFEL features for window-2590
# Extracted TSFEL features for window-2591
# Extracted TSFEL features for window-2592
# Extracted TSFEL features for window-2593
# Extracted TSFEL features for window-2594
# Extracted TSFEL features for window-2595
# Extracted TSFEL features for window-2596
# Extracted TSFEL features for window-2597
# Extracted TSFEL features for window-2598
# Extracted TSFEL features for window-2599
# Extracted TSFEL features for window-2600
# Extracted TSFEL features for window-2601
# Extracted TSFEL features for window-2602
# Extracted TSFEL features for window-2603
# Extracted TSFEL features for window-2604
# Extracted TSFEL features for window-2605
# Extracted TSFEL features for window-2606
# Extracted TSFEL features for window-2607
# Extracted TSFEL features for window-2608
# Extracted TSFEL features for window-2609
# Extracted TSFEL features for window-2610
# Extracted TSFEL features for window-2611
# Extracted TSFEL features for window-2612
# Extracted TSFEL features for window-2613
# Extracted TSFEL features for window-2614
# Extracted TSFEL features for window-2615
# Extracted TSFEL features for window-2616
# Extracted TSFEL features for window-2617
# Extracted TSFEL features for window-2618
# Extracted TSFEL features for window-2619
# Extracted TSFEL features for window-2620
# Extracted TSFEL features for window-2621
# Extracted TSFEL features for window-2622
# Extracted TSFEL features for window-2623
# Extracted TSFEL features for window-2624
# Extracted TSFEL features for window-2625
# Extracted TSFEL features for window-2626
# Extracted TSFEL features for window-2627
# Extracted TSFEL features for window-2628
# Extracted TSFEL features for window-2629
# Extracted TSFEL features for window-2630
# Extracted TSFEL features for window-2631
# Extracted TSFEL features for window-2632
# Extracted TSFEL features for window-2633
# Extracted TSFEL features for window-2634
# Extracted TSFEL features for window-2635
# Extracted TSFEL features for window-2636
# Extracted TSFEL features for window-2637
# Extracted TSFEL features for window-2638
# Extracted TSFEL features for window-2639
# Extracted TSFEL features for window-2640
# Extracted TSFEL features for window-2641
# Extracted TSFEL features for window-2642
# Extracted TSFEL features for window-2643
# Extracted TSFEL features for window-2644
# Extracted TSFEL features for window-2645
# Extracted TSFEL features for window-2646
# Extracted TSFEL features for window-2647
# Extracted TSFEL features for window-2648
# Extracted TSFEL features for window-2649
# Extracted TSFEL features for window-2650
# Extracted TSFEL features for window-2651
# Extracted TSFEL features for window-2652
# Extracted TSFEL features for window-2653
# Extracted TSFEL features for window-2654
# Extracted TSFEL features for window-2655
# Extracted TSFEL features for window-2656
# Extracted TSFEL features for window-2657
# Extracted TSFEL features for window-2658
# Extracted TSFEL features for window-2659
# Extracted TSFEL features for window-2660
# Extracted TSFEL features for window-2661
# Extracted TSFEL features for window-2662
# Extracted TSFEL features for window-2663
# Extracted TSFEL features for window-2664
# Extracted TSFEL features for window-2665
# Extracted TSFEL features for window-2666
# Extracted TSFEL features for window-2667
# Extracted TSFEL features for window-2668
# Extracted TSFEL features for window-2669
# Extracted TSFEL features for window-2670
# Extracted TSFEL features for window-2671
# Extracted TSFEL features for window-2672
# Extracted TSFEL features for window-2673
# Extracted TSFEL features for window-2674
# Extracted TSFEL features for window-2675
# Extracted TSFEL features for window-2676
# Extracted TSFEL features for window-2677
# Extracted TSFEL features for window-2678
# Extracted TSFEL features for window-2679
# Extracted TSFEL features for window-2680
# Extracted TSFEL features for window-2681
# Extracted TSFEL features for window-2682
# Extracted TSFEL features for window-2683
# Extracted TSFEL features for window-2684
# Extracted TSFEL features for window-2685
# Extracted TSFEL features for window-2686
# Extracted TSFEL features for window-2687
# Extracted TSFEL features for window-2688
# Extracted TSFEL features for window-2689
# Extracted TSFEL features for window-2690
# Extracted TSFEL features for window-2691
# Extracted TSFEL features for window-2692
# Extracted TSFEL features for window-2693
# Extracted TSFEL features for window-2694
# Extracted TSFEL features for window-2695
# Extracted TSFEL features for window-2696
# Extracted TSFEL features for window-2697
# Extracted TSFEL features for window-2698
# Extracted TSFEL features for window-2699
# Extracted TSFEL features for window-2700
# Extracted TSFEL features for window-2701
# Extracted TSFEL features for window-2702
# Extracted TSFEL features for window-2703
# Extracted TSFEL features for window-2704
# Extracted TSFEL features for window-2705
# Extracted TSFEL features for window-2706
# Extracted TSFEL features for window-2707
# Extracted TSFEL features for window-2708
# Extracted TSFEL features for window-2709
# Extracted TSFEL features for window-2710
# Extracted TSFEL features for window-2711
# Extracted TSFEL features for window-2712
# Extracted TSFEL features for window-2713
# Extracted TSFEL features for window-2714
# Extracted TSFEL features for window-2715
# Extracted TSFEL features for window-2716
# Extracted TSFEL features for window-2717
# Extracted TSFEL features for window-2718
# Extracted TSFEL features for window-2719
# Extracted TSFEL features for window-2720
# Extracted TSFEL features for window-2721
# Extracted TSFEL features for window-2722
# Extracted TSFEL features for window-2723
# Extracted TSFEL features for window-2724
# Extracted TSFEL features for window-2725
# Extracted TSFEL features for window-2726
# Extracted TSFEL features for window-2727
# Extracted TSFEL features for window-2728
# Extracted TSFEL features for window-2729
# Extracted TSFEL features for window-2730
# Extracted TSFEL features for window-2731
# Extracted TSFEL features for window-2732
# Extracted TSFEL features for window-2733
# Extracted TSFEL features for window-2734
# Extracted TSFEL features for window-2735
# Extracted TSFEL features for window-2736
# Extracted TSFEL features for window-2737
# Extracted TSFEL features for window-2738
# Extracted TSFEL features for window-2739
# Extracted TSFEL features for window-2740
# Extracted TSFEL features for window-2741
# Extracted TSFEL features for window-2742
# Extracted TSFEL features for window-2743
# Extracted TSFEL features for window-2744
# Extracted TSFEL features for window-2745
# Extracted TSFEL features for window-2746
# Extracted TSFEL features for window-2747
# Extracted TSFEL features for window-2748
# Extracted TSFEL features for window-2749
# Extracted TSFEL features for window-2750
# Extracted TSFEL features for window-2751
# Extracted TSFEL features for window-2752
# Extracted TSFEL features for window-2753
# Extracted TSFEL features for window-2754
# Extracted TSFEL features for window-2755
# Extracted TSFEL features for window-2756
# Extracted TSFEL features for window-2757
# Extracted TSFEL features for window-2758
# Extracted TSFEL features for window-2759
# Extracted TSFEL features for window-2760
# Extracted TSFEL features for window-2761
# Extracted TSFEL features for window-2762
# Extracted TSFEL features for window-2763
# Extracted TSFEL features for window-2764
# Extracted TSFEL features for window-2765
# Extracted TSFEL features for window-2766
# Extracted TSFEL features for window-2767
# Extracted TSFEL features for window-2768
# Extracted TSFEL features for window-2769
# Extracted TSFEL features for window-2770
# Extracted TSFEL features for window-2771
# Extracted TSFEL features for window-2772
# Extracted TSFEL features for window-2773
# Extracted TSFEL features for window-2774
# Extracted TSFEL features for window-2775
# Extracted TSFEL features for window-2776
# Extracted TSFEL features for window-2777
# Extracted TSFEL features for window-2778
# Extracted TSFEL features for window-2779
# Extracted TSFEL features for window-2780
# Extracted TSFEL features for window-2781
# Extracted TSFEL features for window-2782
# Extracted TSFEL features for window-2783
# Extracted TSFEL features for window-2784
# Extracted TSFEL features for window-2785
# Extracted TSFEL features for window-2786
# Extracted TSFEL features for window-2787
# Extracted TSFEL features for window-2788
# Extracted TSFEL features for window-2789
# Extracted TSFEL features for window-2790
# Extracted TSFEL features for window-2791
# Extracted TSFEL features for window-2792
# Extracted TSFEL features for window-2793
# Extracted TSFEL features for window-2794
# Extracted TSFEL features for window-2795
# Extracted TSFEL features for window-2796
# Extracted TSFEL features for window-2797
# Extracted TSFEL features for window-2798
# Extracted TSFEL features for window-2799
# Extracted TSFEL features for window-2800
# Extracted TSFEL features for window-2801
# Extracted TSFEL features for window-2802
# Extracted TSFEL features for window-2803
# Extracted TSFEL features for window-2804
# Extracted TSFEL features for window-2805
# Extracted TSFEL features for window-2806
# Extracted TSFEL features for window-2807
# Extracted TSFEL features for window-2808
# Extracted TSFEL features for window-2809
# Extracted TSFEL features for window-2810
# Extracted TSFEL features for window-2811
# Extracted TSFEL features for window-2812
# Extracted TSFEL features for window-2813
# Extracted TSFEL features for window-2814
# Extracted TSFEL features for window-2815
# Extracted TSFEL features for window-2816
# Extracted TSFEL features for window-2817
# Extracted TSFEL features for window-2818
# Extracted TSFEL features for window-2819
# Extracted TSFEL features for window-2820
# Extracted TSFEL features for window-2821
# Extracted TSFEL features for window-2822
# Extracted TSFEL features for window-2823
# Extracted TSFEL features for window-2824
# Extracted TSFEL features for window-2825
# Extracted TSFEL features for window-2826
# Extracted TSFEL features for window-2827
# Extracted TSFEL features for window-2828
# Extracted TSFEL features for window-2829
# Extracted TSFEL features for window-2830
# Extracted TSFEL features for window-2831
# Extracted TSFEL features for window-2832
# Extracted TSFEL features for window-2833
# Extracted TSFEL features for window-2834
# Extracted TSFEL features for window-2835
# Extracted TSFEL features for window-2836
# Extracted TSFEL features for window-2837
# Extracted TSFEL features for window-2838
# Extracted TSFEL features for window-2839
# Extracted TSFEL features for window-2840
# Extracted TSFEL features for window-2841
# Extracted TSFEL features for window-2842
# Extracted TSFEL features for window-2843
# Extracted TSFEL features for window-2844
# Extracted TSFEL features for window-2845
# Extracted TSFEL features for window-2846
# Extracted TSFEL features for window-2847
# Extracted TSFEL features for window-2848
# Extracted TSFEL features for window-2849
# Extracted TSFEL features for window-2850
# Extracted TSFEL features for window-2851
# Extracted TSFEL features for window-2852
# Extracted TSFEL features for window-2853
# Extracted TSFEL features for window-2854
# Extracted TSFEL features for window-2855
# Extracted TSFEL features for window-2856
# Extracted TSFEL features for window-2857
# Extracted TSFEL features for window-2858
# Extracted TSFEL features for window-2859
# Extracted TSFEL features for window-2860
# Extracted TSFEL features for window-2861
# Extracted TSFEL features for window-2862
# Extracted TSFEL features for window-2863
# Extracted TSFEL features for window-2864
# Extracted TSFEL features for window-2865
# Extracted TSFEL features for window-2866
# Extracted TSFEL features for window-2867
# Extracted TSFEL features for window-2868
# Extracted TSFEL features for window-2869
# Extracted TSFEL features for window-2870
# Extracted TSFEL features for window-2871
# Extracted TSFEL features for window-2872
# Extracted TSFEL features for window-2873
# Extracted TSFEL features for window-2874
# Extracted TSFEL features for window-2875
# Extracted TSFEL features for window-2876
# Extracted TSFEL features for window-2877
# Extracted TSFEL features for window-2878
# Extracted TSFEL features for window-2879
# Extracted TSFEL features for window-2880
# Extracted TSFEL features for window-2881
# Extracted TSFEL features for window-2882
# Extracted TSFEL features for window-2883
# Extracted TSFEL features for window-2884
# Extracted TSFEL features for window-2885
# Extracted TSFEL features for window-2886
# Extracted TSFEL features for window-2887
# Extracted TSFEL features for window-2888
# Extracted TSFEL features for window-2889
# Extracted TSFEL features for window-2890
# Extracted TSFEL features for window-2891
# Extracted TSFEL features for window-2892
# Extracted TSFEL features for window-2893
# Extracted TSFEL features for window-2894
# Extracted TSFEL features for window-2895
# Extracted TSFEL features for window-2896
# Extracted TSFEL features for window-2897
# Extracted TSFEL features for window-2898
# Extracted TSFEL features for window-2899
# Extracted TSFEL features for window-2900
# Extracted TSFEL features for window-2901
# Extracted TSFEL features for window-2902
# Extracted TSFEL features for window-2903
# Extracted TSFEL features for window-2904
# Extracted TSFEL features for window-2905
# Extracted TSFEL features for window-2906
# Extracted TSFEL features for window-2907
# Extracted TSFEL features for window-2908
# Extracted TSFEL features for window-2909
# Extracted TSFEL features for window-2910
# Extracted TSFEL features for window-2911
# Extracted TSFEL features for window-2912
# Extracted TSFEL features for window-2913
# Extracted TSFEL features for window-2914
# Extracted TSFEL features for window-2915
# Extracted TSFEL features for window-2916
# Extracted TSFEL features for window-2917
# Extracted TSFEL features for window-2918
# Extracted TSFEL features for window-2919
# Extracted TSFEL features for window-2920
# Extracted TSFEL features for window-2921
# Extracted TSFEL features for window-2922
# Extracted TSFEL features for window-2923
# Extracted TSFEL features for window-2924
# Extracted TSFEL features for window-2925
# Extracted TSFEL features for window-2926
# Extracted TSFEL features for window-2927
# Extracted TSFEL features for window-2928
# Extracted TSFEL features for window-2929
# Extracted TSFEL features for window-2930
# Extracted TSFEL features for window-2931
# Extracted TSFEL features for window-2932
# Extracted TSFEL features for window-2933
# Extracted TSFEL features for window-2934
# Extracted TSFEL features for window-2935
# Extracted TSFEL features for window-2936
# Extracted TSFEL features for window-2937
# Extracted TSFEL features for window-2938
# Extracted TSFEL features for window-2939
# Extracted TSFEL features for window-2940
# Extracted TSFEL features for window-2941
# Extracted TSFEL features for window-2942
# Extracted TSFEL features for window-2943
# Extracted TSFEL features for window-2944
# Extracted TSFEL features for window-2945
# Extracted TSFEL features for window-2946
# Extracted TSFEL features for window-2947

# %%
y_train_tsfel=y_train_raw
y_test_tsfel=y_test_raw

# %% [markdown]
# ## **Standardization of Data**

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler_raw=StandardScaler()
scaled_X_train_raw=scaler_raw.fit_transform(X_train_raw.reshape(X_train_raw.shape[0]*X_train_raw.shape[1],X_train_raw.shape[2]))
scaled_X_test_raw=scaler_raw.fit_transform(X_test_raw.reshape(X_test_raw.shape[0]*X_test_raw.shape[1],X_test_raw.shape[2]))
scaled_X_train_raw=scaled_X_train_raw.reshape(7352,128,3)
scaled_X_test_raw=scaled_X_test_raw.reshape(2947, 128, 3)
print(scaled_X_train_raw.shape)
print(scaled_X_test_raw.shape)
# Out:
# (7352, 128, 3)
# (2947, 128, 3)

# %%
scaler_dataset_feat=StandardScaler()
scaled_X_train_dataset_feat=scaler_dataset_feat.fit_transform(X_train_dataset_feat)
scaled_X_test_dataset_feat=scaler_dataset_feat.fit_transform(X_test_dataset_feat)
print(scaled_X_train_dataset_feat.shape)
print(scaled_X_test_dataset_feat.shape)
# Out:
# (7352, 561)
# (2947, 561)

# %%
scaler_tsfel=StandardScaler()
scaled_X_train_tsfel=scaler_tsfel.fit_transform(X_train_tsfel)
scaled_X_test_tsfel=scaler_tsfel.fit_transform(X_test_tsfel)
print(scaled_X_train_tsfel.shape)
print(scaled_X_test_tsfel.shape)
# Out:
# (7352, 93)
# (2947, 93)

# %% [markdown]
# # **Classification**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
def get_metrics(y_test,y_pred, model_name,dataset_name):
    accuracy=accuracy_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred, average='weighted')
    precision=precision_score(y_test,y_pred, average='weighted')
    print(f'Accuracy of {model_name} on {dataset_name}: {accuracy}')
    print(f'Recall of {model_name} on {dataset_name}: {recall}')
    print(f'Precision of {model_name} on {dataset_name}: {precision}')
    return accuracy, recall, precision

# %% [markdown]
# # **a. Use UCI HAR dataset and build a model to predict various activity classes.**

# %% [markdown]
# ## **Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ###  1. On Raw Accelerometer Data

# %%
X_train_raw_for_dt=scaled_X_train_raw.reshape(-1,3)
y_train_raw_for_dt=np.repeat(y_train_raw,128)
X_test_raw_for_dt=scaled_X_test_raw.reshape(-1,3)
y_test_raw_for_dt=np.repeat(y_test_raw,128)
print(y_train_raw_for_dt.shape)
print(y_test_raw_for_dt.shape)
print(X_train_raw_for_dt.shape)
print(X_test_raw_for_dt.shape)
# Out:
# (941056,)
# (377216,)
# (941056, 3)
# (377216, 3)

# %%
decision_tree_on_raw_data=DecisionTreeClassifier(random_state=42)
decision_tree_on_raw_data.fit(X_train_raw_for_dt,y_train_raw_for_dt)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt_raw=decision_tree_on_raw_data.predict(X_test_raw_for_dt)

# %%
acc_raw_dt, recall_raw_dt, prec_raw_dt=get_metrics(y_test_raw_for_dt,y_pred_dt_raw, 'Decision Tree Classifier', 'Raw Data')
# Out:
# Accuracy of Decision Tree Classifier on Raw Data: 0.554189111808619
# Recall of Decision Tree Classifier on Raw Data: 0.554189111808619
# Precision of Decision Tree Classifier on Raw Data: 0.5997412709413114

# %% [markdown]
# ### 2. On Features provided by the Author

# %%
decision_tree_on_dataset_feat=DecisionTreeClassifier(random_state=42)
decision_tree_on_dataset_feat.fit(scaled_X_train_dataset_feat,y_train_dataset_feat)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_on_dataset_feat_dt=decision_tree_on_dataset_feat.predict(scaled_X_test_dataset_feat)

# %%
acc_dataset_feat_dt, recall_dataset_feat_dt, prec_dataset_feat_dt=get_metrics(y_test_dataset_feat,y_pred_on_dataset_feat_dt, 'Decision Tree Classifier', 'Dataset Features')
# Out:
# Accuracy of Decision Tree Classifier on Dataset Features: 0.8116728876823889
# Recall of Decision Tree Classifier on Dataset Features: 0.8116728876823889
# Precision of Decision Tree Classifier on Dataset Features: 0.8260657713785309

# %% [markdown]
# ### 3. On TSFEL Features

# %%
decision_tree_on_tsfel_feat=DecisionTreeClassifier(random_state=42)
decision_tree_on_tsfel_feat.fit(scaled_X_train_tsfel, y_train_tsfel)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_on_tsfel_feat_dt=decision_tree_on_tsfel_feat.predict(scaled_X_test_tsfel)

# %%
acc_tsfel_dt, recall_tsfel_dt, prec_tsfel_dt= get_metrics(y_test_tsfel, y_pred_on_tsfel_feat_dt,'Decision Tree Classifier', 'TSFEL features')
# Out:
# Accuracy of Decision Tree Classifier on TSFEL features: 0.7539871055310485
# Recall of Decision Tree Classifier on TSFEL features: 0.7539871055310485
# Precision of Decision Tree Classifier on TSFEL features: 0.7561649384753775

# %% [markdown]
# ## **b. Use Deep Learning models like LSTM, 1D Cnns for modeling using inertial sensor data (Raw accelerometer data). Do not train DL methods on already existing features provided by the authors.**

# %%
X_train_tensor=torch.tensor(scaled_X_train_raw,dtype=torch.float32)
X_test_tensor=torch.tensor(scaled_X_test_raw, dtype=torch.float32)
y_train_tensor=torch.tensor(y_train_raw, dtype=torch.long)
y_test_tensor=torch.tensor(y_test_raw, dtype=torch.long)

# %% [markdown]
# ### **Using 1D CNN**

# %%
X_train_for_cnn=X_train_tensor.reshape(X_train_tensor.shape[0],X_train_tensor.shape[2],X_train_tensor.shape[1])
y_train_for_cnn=y_train_tensor
X_test_for_cnn=X_test_tensor.reshape(X_test_tensor.shape[0],X_test_tensor.shape[2],X_test_tensor.shape[1])
y_test_for_cnn=y_test_tensor

# %%
X_train_for_cnn.shape
# Out:
# torch.Size([7352, 3, 128])

# %%
train_dataset_cnn=torch.utils.data.TensorDataset(X_train_for_cnn,y_train_for_cnn)
train_loader_cnn=torch.utils.data.DataLoader(train_dataset_cnn, batch_size=32, shuffle=False)

# %%
test_dataset_cnn=torch.utils.data.TensorDataset(X_test_for_cnn,y_test_for_cnn)
test_loader_cnn=torch.utils.data.DataLoader(test_dataset_cnn, batch_size=32, shuffle=False)

# %%
class cnn_1d(nn.Module):
    def __init__(self, n_features, n_classes, n_steps):
        super(cnn_1d, self).__init__()
        self.conv_layer1=nn.Conv1d(in_channels=n_features, out_channels=32, kernel_size=4)
        self.pooling_layer1=nn.MaxPool1d(2,1)
        self.conv_layer2=nn.Conv1d(in_channels=32, out_channels=64, kernel_size=4)
        self.pooling_layer2=nn.MaxPool1d(2,1)
        self.fc1=nn.Linear(64*120,128)
        self.fc2=nn.Linear(128,n_classes)

    def forward(self, x):
        x=self.conv_layer1(x)
        x=F.relu(x)
        x=self.pooling_layer1(x)
        x=self.conv_layer2(x)
        x=F.relu(x)
        x=self.pooling_layer2(x)
        x=x.view(x.size(0),-1)
        x=self.fc1(x)
        x=F.relu(x)
        x=self.fc2(x) 
        return x

# %%
cnn_model_1d=cnn_1d(3,6,128)

# %%
def train_cnn_model(model, train_dataset, epochs):
    criterion=nn.CrossEntropyLoss()
    optimizer=optim.Adam(model.parameters(), lr=0.005)

    for epoch in range(epochs):
        epoch_train_loss=0
        batch_train_losses=[]

        for X_train_batch, y_train_batch in train_dataset:
            optimizer.zero_grad()
            results=model(X_train_batch)
            loss=criterion(results, y_train_batch-1)
            loss.backward()
            optimizer.step()
            batch_train_losses.append(loss.item())
        
        epoch_train_loss=sum(batch_train_losses)/len(batch_train_losses)

        print(f'Epoch : {epoch}, training-loss: {epoch_train_loss}')

# %%
train_cnn_model(cnn_model_1d, train_loader_cnn, 25)
# Out:
# Epoch : 0, training-loss: 1.1469657893778513
# Epoch : 1, training-loss: 0.7625510327072571
# Epoch : 2, training-loss: 0.6099000197531574
# Epoch : 3, training-loss: 0.5954988334793597
# Epoch : 4, training-loss: 0.5878152448643484
# Epoch : 5, training-loss: 0.5302365609667385
# Epoch : 6, training-loss: 0.4863609299101644
# Epoch : 7, training-loss: 0.47141312593366425
# Epoch : 8, training-loss: 0.4392689578643236
# Epoch : 9, training-loss: 0.4063283897462458
# Epoch : 10, training-loss: 0.45196229147584194
# Epoch : 11, training-loss: 0.3675628495536449
# Epoch : 12, training-loss: 0.35116898210900493
# Epoch : 13, training-loss: 0.34198004993643377
# Epoch : 14, training-loss: 0.35121365898471396
# Epoch : 15, training-loss: 0.30174316928788236
# Epoch : 16, training-loss: 0.2847441636587736
# Epoch : 17, training-loss: 0.266231406557294
# Epoch : 18, training-loss: 0.25064979059725767
# Epoch : 19, training-loss: 0.24493582316730603
# Epoch : 20, training-loss: 0.238267766703145
# Epoch : 21, training-loss: 0.33502283436091207
# Epoch : 22, training-loss: 0.2617464563942151
# Epoch : 23, training-loss: 0.25238312918508576
# Epoch : 24, training-loss: 0.20039201635464318

# %%
def get_predictions_cnn(model, test_dataset):
    model.eval()
    preds=[]
    for X_test_batch, y_test_batch in test_dataset:
        with torch.no_grad():
            results=model(X_test_batch)
            batch_preds=results.argmax(dim=1)+1
            preds.extend(batch_preds)
    return preds

# %%
y_preds_from_cnn=get_predictions_cnn(cnn_model_1d, test_loader_cnn)

# %%
acc_cnn, recall_cnn, prec_cnn=get_metrics(y_test_for_cnn,y_preds_from_cnn, '1D-CNN', 'Raw Data')
# Out:
# Accuracy of 1D CNN on Raw Data: 0.8082796063793688
# Recall of 1D CNN on Raw Data: 0.8082796063793688
# Precision of 1D CNN on Raw Data: 0.8129413350103818

# %% [markdown]
# ## **Using LSTMs**

# %%
X_train_for_lstm=X_train_tensor
y_train_for_lstm=y_train_tensor
X_test_for_lstm=X_test_tensor
y_test_for_lstm=y_test_tensor
# Out:
# C:\Users\Lenova\AppData\Local\Temp\ipykernel_31200\388249849.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train_for_lstm=torch.tensor(X_train_tensor, dtype=torch.float32)
# C:\Users\Lenova\AppData\Local\Temp\ipykernel_31200\388249849.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test_for_lstm=torch.tensor(X_test_tensor, dtype=torch.float32)

# %%
train_dataset_lstm=torch.utils.data.TensorDataset(X_train_for_lstm,y_train_for_lstm)
train_loader_lstm=torch.utils.data.DataLoader(train_dataset_lstm, batch_size=32, shuffle=False)
test_dataset_lstm=torch.utils.data.TensorDataset(X_test_for_lstm,y_test_for_lstm)
test_loader_lstm=torch.utils.data.DataLoader(test_dataset_lstm, batch_size=32, shuffle=False)

# %%
print(type(X_train_for_lstm)) 
print(type(y_train_for_lstm))  
print(X_train_for_lstm.shape)
print(y_train_for_lstm.shape)
print(y_train_for_lstm)
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# torch.Size([7352, 128, 3])
# torch.Size([7352])
# tensor([5, 5, 5,  ..., 2, 2, 2])

# %%
print(X_train_for_lstm.shape)
# Out:
# torch.Size([7352, 128, 3])

# %%
class lstm_model(nn.Module):
    def __init__(self, n_feat, n_hidden, n_layers, n_classes):
        super(lstm_model, self).__init__()
        self.n_hidden=n_hidden
        self.n_layers=n_layers
        self.lstm=nn.LSTM(n_feat, n_hidden, n_layers, batch_first=True)
        self.fc=nn.Linear(n_hidden, n_classes)
    
    def forward(self, x, h0=None, c0=None):
        if h0 is None or c0 is None:
            h0=torch.zeros(self.n_layers, x.size(0), self.n_hidden)
            c0=torch.zeros(self.n_layers, x.size(0), self.n_hidden)
        result, (hn, cn)=self.lstm(x, (h0, c0))
        last_hidden_state=result[:,-1,:]
        output=self.fc(last_hidden_state)
        return output, (hn, cn)

# %%
def train_lstm_model(model, train_dataset, epochs):
    criterion=nn.CrossEntropyLoss()
    optimizer=optim.Adam(model.parameters(), lr=0.005)

    for epoch in range(epochs):
        epoch_train_loss=0
        batch_train_losses=[]

        hn=None
        cn=None

        for X_train_batch, y_train_batch in train_dataset:
            optimizer.zero_grad()
            batch_size = X_train_batch.size(0)
            if hn is not None and hn.size(1) != batch_size:
                hn, cn=None, None
            results, (hn, cn)=model(X_train_batch, hn, cn)
            loss=criterion(results, y_train_batch-1)
            loss.backward()
            optimizer.step()
            batch_train_losses.append(loss.item())
            hn, cn=hn.detach(), cn.detach()
        
        epoch_train_loss=sum(batch_train_losses)/len(batch_train_losses)

        print(f'Epoch : {epoch}, training-loss: {epoch_train_loss}')

# %%
lstm_classifier=lstm_model(3,256,3,6)

# %%
train_lstm_model(lstm_classifier,train_loader_lstm, 25)
# Out:
# Epoch : 0, training-loss: 1.809502503146296
# Epoch : 1, training-loss: 1.8011861687121185
# Epoch : 2, training-loss: 1.7873257870259491
# Epoch : 3, training-loss: 1.7794476384701936
# Epoch : 4, training-loss: 1.6716562853073296
# Epoch : 5, training-loss: 1.546207728722821
# Epoch : 6, training-loss: 1.5044316898869432
# Epoch : 7, training-loss: 1.4444813661601232
# Epoch : 8, training-loss: 1.4322184317137885
# Epoch : 9, training-loss: 1.364504798858062
# Epoch : 10, training-loss: 1.3572067411049553
# Epoch : 11, training-loss: 1.3462289059291714
# Epoch : 12, training-loss: 1.2691727783692919
# Epoch : 13, training-loss: 1.2871195808700893
# Epoch : 14, training-loss: 1.1243067623804446
# Epoch : 15, training-loss: 0.9954083297887574
# Epoch : 16, training-loss: 1.6323022517173187
# Epoch : 17, training-loss: 1.37065323571796
# Epoch : 18, training-loss: 1.3648579984903335
# Epoch : 19, training-loss: 1.3434341848382483
# Epoch : 20, training-loss: 1.3412390948556687
# Epoch : 21, training-loss: 1.2762162666443897
# Epoch : 22, training-loss: 1.3330120325736377
# Epoch : 23, training-loss: 1.3631175805693088
# Epoch : 24, training-loss: 1.31564323435659

# %%
def get_predictions_lstm(model, test_dataset):
    model.eval()
    preds=[]
    for X_test_batch, y_test_batch in test_dataset:
        with torch.no_grad():
            results=model(X_test_batch)
            batch_preds=results[0].argmax(dim=1)+1
            preds.extend(batch_preds)
    return preds

# %%
y_preds_from_lstm=get_predictions_lstm(lstm_classifier, test_loader_lstm)

# %%
acc_lstm, recall_lstm, prec_lstm=get_metrics(y_test_for_lstm,y_preds_from_lstm, 'LSTM', 'Raw Data')
# Out:
# Accuracy of LSTM on Raw Data: 0.4054971157108924
# Recall of LSTM on Raw Data: 0.4054971157108924
# Precision of LSTM on Raw Data: 0.3612564932570117
# c:\Users\Lenova\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## **c. How can the same be done using Machine Learning models like Random forest, SVM, and Logistic regression? Use the TSFEL library to generate features from Inertial data. Compare the performance of models trained on your generated features versus features provided by the authors.**

# %% [markdown]
# ### **Using Random Forest on various Datasets**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model_tsfel=RandomForestClassifier(n_estimators=20, random_state=42, bootstrap=True)
rf_model_tsfel.fit(scaled_X_train_tsfel,y_train_tsfel)
y_pred_rf_tsfel=rf_model_tsfel.predict(scaled_X_test_tsfel)
acc_tsfel_rf, recall_tsfel_rf, prec_tsfel_rf=get_metrics(y_test_tsfel,y_pred_rf_tsfel, 'Random Forest Classifier', 'TSFEL-Features')
# Out:
# Accuracy of Random Forest Classifier on TSFEL-Features: 0.7824906684764167
# Recall of Random Forest Classifier on TSFEL-Features: 0.7824906684764167
# Precision of Random Forest Classifier on TSFEL-Features: 0.786453974620687

# %%
rf_model_raw=RandomForestClassifier(n_estimators=20, random_state=42, bootstrap=True)
rf_model_raw.fit(X_train_raw_for_dt,y_train_raw_for_dt)
y_pred_rf_raw=rf_model_raw.predict(X_test_raw_for_dt)
acc_raw_rf, recall_raw_rf, prec_raw_rf=get_metrics(y_test_raw_for_dt,y_pred_rf_raw, 'Random Forest Classifier', 'Raw Data')
# Out:
# Accuracy of Random Forest Classifier on Raw Data: 0.5969126442144553
# Recall of Random Forest Classifier on Raw Data: 0.5969126442144553
# Precision of Random Forest Classifier on Raw Data: 0.6299532501663687

# %%
rf_model_dataset_feat=RandomForestClassifier(n_estimators=20, random_state=42, bootstrap=True)
rf_model_dataset_feat.fit(scaled_X_train_dataset_feat,y_train_dataset_feat)
y_pred_rf_dataset_feat=rf_model_dataset_feat.predict(scaled_X_test_dataset_feat)
acc_dataset_feat_rf, recall_dataset_feat_rf, prec_dataset_feat_rf=get_metrics(y_test_dataset_feat,y_pred_rf_dataset_feat, 'Random Forest Classifier', 'Dataset Features')
# Out:
# c:\Users\Lenova\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Accuracy of Random Forest Classifier on Dataset Features: 0.8897183576518494
# Recall of Random Forest Classifier on Dataset Features: 0.8897183576518494
# Precision of Random Forest Classifier on Dataset Features: 0.8944630699119097

# %% [markdown]
# ### **Using Logistic Regression on various Datasets**

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg_model_tsfel=LogisticRegression()
log_reg_model_tsfel.fit(scaled_X_train_tsfel,y_train_tsfel)
y_pred_log_reg_tsfel=log_reg_model_tsfel.predict(scaled_X_test_tsfel)
acc_tsfel_log_reg, recall_tsfel_log_reg, prec_tsfel_log_reg=get_metrics(y_test_tsfel,y_pred_log_reg_tsfel, 'Logistic Regression', 'TSFEL-Features')
# Out:
# Accuracy of Logistic Regression on TSFEL-Features: 0.8109942314217848
# Recall of Logistic Regression on TSFEL-Features: 0.8109942314217848
# Precision of Logistic Regression on TSFEL-Features: 0.8135119489262421
# c:\Users\Lenova\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
log_reg_model_raw=LogisticRegression()
log_reg_model_raw.fit(X_train_raw_for_dt,y_train_raw_for_dt)
y_pred_log_reg_raw=log_reg_model_raw.predict(X_test_raw_for_dt)
acc_raw_log_reg, recall_raw_log_reg, prec_raw_log_reg=get_metrics(y_test_raw_for_dt,y_pred_log_reg_raw, 'Logistic Regression', 'Raw Data')
# Out:
# Accuracy of Logistic Regression on Raw Data: 0.49966862487275193
# Recall of Logistic Regression on Raw Data: 0.49966862487275193
# Precision of Logistic Regression on Raw Data: 0.4684431585481109

# %%
log_reg_model_dataset_feat=LogisticRegression()
log_reg_model_dataset_feat.fit(scaled_X_train_dataset_feat,y_train_dataset_feat)
y_pred_log_reg_dataset_feat=log_reg_model_dataset_feat.predict(scaled_X_test_dataset_feat)
acc_dataset_feat_log_reg, recall_dataset_feat_log_reg, prec_dataset_feat_log_reg=get_metrics(y_test_dataset_feat,y_pred_log_reg_dataset_feat, 'Logistic Regression', 'Dataset Features')
# Out:
# c:\Users\Lenova\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy of Logistic Regression on Dataset Features: 0.9630132337970818
# Recall of Logistic Regression on Dataset Features: 0.9630132337970818
# Precision of Logistic Regression on Dataset Features: 0.963231711765267
# c:\Users\Lenova\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## **Tabularizing Observations**

# %%
models=['Decision Tree', 'Random Forest', 'Logistic Regression', '1D-CNN', 'LSTM']
metrics=['Accuracy', 'Precision', 'Recall']

# %%
df_1=pd.DataFrame(columns=metrics, index=models)

# %%
df_1.loc['Decision Tree']=(acc_raw_dt, prec_raw_dt, recall_raw_dt)
df_1.loc['Random Forest']=(acc_raw_rf, prec_raw_rf, recall_raw_rf)
df_1.loc['Logistic Regression']=(acc_raw_log_reg, prec_raw_log_reg, recall_raw_log_reg)
df_1.loc['1D-CNN']=(acc_cnn, prec_cnn, recall_cnn)
df_1.loc['LSTM']=(acc_lstm, prec_lstm, recall_lstm)

# %%
ml_models=['Decision Tree', 'Random Forest', 'Logistic Regression']
classes=['Dataset Features', 'TSFEL features']

# %%
performance_dict={
    "Dataset Features": {
        "Decision Tree": {
                          "Accuracy": acc_dataset_feat_dt,
                          "Precision":prec_dataset_feat_dt,
                          "Recall": recall_dataset_feat_dt
                        },
        "Random Forest": {
                           "Accuracy":acc_dataset_feat_rf,
                           "Precision":prec_dataset_feat_rf,
                            "Recall":recall_dataset_feat_rf
                        },
        "Logistic Regression": {
                                "Accuracy":acc_dataset_feat_log_reg,
                                "Precision":prec_dataset_feat_log_reg,
                                "Recall":recall_dataset_feat_log_reg
                            },
    },
    "TSFEL Features": {
        "Decision Tree": {
                           "Accuracy":acc_tsfel_dt,
                           "Precision": prec_tsfel_dt,
                           "Recall":recall_tsfel_dt
                             },
        "Random Forest": {
                          "Accuracy": acc_tsfel_rf,
                          "Precision": prec_tsfel_rf,
                          "Recall": recall_tsfel_rf
                          },
        "Logistic Regression": {
                                "Accuracy": acc_tsfel_log_reg,
                                "Precision": prec_tsfel_log_reg,
                                "Recall": recall_tsfel_log_reg
                            }
    }
}

# %%
df_performance = pd.DataFrame.from_dict(
    {(feature_set, model): metrics for feature_set, models in performance_dict.items() for model, metrics in models.items()},
    orient="index"
)

# %% [markdown]
# ## **Comparision: ML models vs. DL Models**

# %%
df_1
# Out:
#                      Accuracy Precision    Recall
# Decision Tree        0.554189  0.599741  0.554189
# Random Forest        0.596913  0.629953  0.596913
# Logistic Regression  0.499669  0.468443  0.499669
# 1D-CNN                0.80828  0.812941   0.80828
# LSTM                 0.405497  0.361256  0.405497

# %% [markdown]
# ## **Comparision: ML models on dataset features vs. TSFEL features**

# %%
df_performance
# Out:
#                                       Accuracy  Precision    Recall
# Dataset Features Decision Tree        0.811673   0.826066  0.811673
#                  Random Forest        0.889718   0.894463  0.889718
#                  Logistic Regression  0.963013   0.963232  0.963013
# TSFEL Features   Decision Tree        0.753987   0.756165  0.753987
#                  Random Forest        0.782491   0.786454  0.782491
#                  Logistic Regression  0.810994   0.813512  0.810994

# %% [markdown]
# # **Summary of the Task:**

# %% [markdown]
# ## In this task, we built various models on the the given as well as the extracted dataset.
# ## **Dataset Preparation:**
# ## We had 7352 training data windows and 2947 testing data windows each with 128 time steps and 3 features indicating the triaxial acceleration, as raw inertial signals. We also had 561 length feature vector for each window of both train and test data.
# ## 1. Generated train-test data from raw inertial signals of accelerometer
# ## 2. Generated train-test data from given feature vectors
# ## 3. Extracted 93-length feature vector from each window of train-test data using TSFEL
#
# ## **Models Trained:**
# ### **1. ML models (trained on all 3 types of datasets):**
# ### a. Decision Tree
# ### b. Random Forest
# ### c. Logistic Regression
# ### **2. DL models (trained only on raw inertial signals):**
# ### a. 1D-CNN
# ### b. LSTM
#
#
# ## **Observations and Insights:**
# ## Looking at the tables we obtained about various performance metrics of the models, it was observed and concluded that:
# ### 1. 1D CNN had the best performence on Human-Activity-Recognition. It is understood as the algorithm is effective in extracing features from sequential data like time series
# ### 2. Random Forest performed better than other ML models, evidently due to ensemble methods. But still it performs poorly compared to CNN, as it is stii ineffective of grasping important features and patterns in the time-series data.
# ### 3. Logistic Regression has worst performance among ML models, which suggests linear decision boundries are not sufficient for such dataset.
# ### 4. LSTM, ideally, should effectively handle sequential data as they can store sequential dependencies. They should outperform ML models. But here, we observe that they have the worst performance.
# ### a. Inefficient training or poor choice of hyperparameters.
# ### b. Lack of proper optimization techniques (e.g., learning rate tuning, dropout, batch size).
# ### c. Insufficient dataset size for LSTM to learn long-term dependencies effectively.
# ### d. High training time under the given parameter set, making optimization difficult.
# ## This indicates that Deep Learning techniques are super-efficient in extracting meaningful pattrns and features from sequential data, as compared to the traditional Machine Learning algorithms. However, seeing the case of LSTMs here in our notebook, it is also advisable to opt for better data-preprocessing, hyperparameter fine-tuning, and optimization techniques to improve the results.
#
# ## Furthermore, we see that models trained on features given by authors fairly outperform those tained on TSFEL-extrcted features. This tells us that the given features-set gives more domain-specific and informative set of features proving it to be the best choice for model training. Features extracted from TSFEL can be less informative and redundant, causing the model to drop in accuracy.
